# %% [markdown]
# # Spotify Project - Jeremias Figueroa

# %% [markdown]
# *** This is a working document.
#
# *** Next steps include more analytics on the data itself, clustering the songs together based off different characteristics, and performing regressions to see if different characteristics affect popularity or not.

# %% [markdown]
# First, import the following:

# %%
import configparser
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import json
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')

import gspread
from google.oauth2 import service_account

# %% [markdown]
# ## Spotify API Client Credientials

# %% [markdown]
# Using https://developer.spotify.com/dashboard/applications, make an application and get client ID and client secret ID

# %%
#use your own client ID and slient secret ID
client_credentials_manager = SpotifyClientCredentials(client_id="0529e7f5553243d99b80a5c66a21e89c", 
                                                      client_secret="f18bab3e7e8d4167b380361f5a35f6b3")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## Importing Google Sheet

# %% [markdown]
# Use song information from the following Google Sheet: https://docs.google.com/spreadsheets/d/165OdLYjLt4AgeqP5S5PunRonDkpp28nueHLFv994bPk/edit?usp=sharing
#
# This Google Sheet is a collection of hit songs from HITS Daily Double, a music industry trade publication, and their weekly Overall Song Streams chart. The data includes how many times a song was streamed week-to-week for most weeks since 2017 (with the exception of holiday weeks, weeks when holiday music regularly push out non-holiday songs out of the top spots of music charts).

# %%
#service account
sa = gspread.service_account()

#sheet
sh = sa.open("HITS Streaming Songs")

#worksheet
wks = sh.worksheet("HITS Streaming Songs")

#uses all values in the worksheet for the data frame
gsheets_df = pd.DataFrame(wks.get_all_values())

header = gsheets_df.iloc[0] #isolate first row as header
gsheets_df = gsheets_df[1:] #get rid of header in original df
gsheets_df.columns = header

#set 'song_id' as index
gsheets_df = gsheets_df.set_index('index')

gsheets_df['title'] = gsheets_df['title'].str.rstrip(' ')
gsheets_df['artist'] = gsheets_df['artist'].str.rstrip(' ')
gsheets_df['album'] = gsheets_df['album'].str.rstrip(' ')

#convert index from string to int
gsheets_df.index = gsheets_df.index.astype(int)

#fill in blank values with 0
gsheets_df = gsheets_df.replace(r'^\s*$', "0", regex=True)

#convert all numbers-as-strings to numbers from row 4 in python's index and onwards
for col_name in gsheets_df.columns.to_list()[4:len(gsheets_df.columns.to_list())]:
    
    #get rid of strings' commas and convert strings to integers
    gsheets_df[col_name] = gsheets_df[col_name].str.replace(',','').astype('int')
    
#turn peak_date strings to date format
gsheets_df['peak_date'] = pd.to_datetime(gsheets_df['peak_date'])

gsheets_df
# Out:
# 0                              title             artist  \
# index
# 1                            The One   The Chainsmokers
# 2                         Sacrifices              Drake
# 3                             Closer   The Chainsmokers
# 4                            Starboy         The Weeknd
# 5                    Get It Together              Drake
# ...                              ...                ...
# 1985                    Freaky Deaky               Tyga
# 1986                   Banking On Me              Gunna
# 1987                 Numb Little Bug         Em Beihold
# 1988   Rocking A Cardigan in Atlanta  lil Shordie Scott
# 1989      Bam Bam (feat. Ed Sheeran)     Camila Cabello
#
# 0                              album  peak_date  streams_2017_to_present  \
# index
# 1             Memories...Do Not Open 2017-01-08                  7309244
# 2                          More Life 2017-03-18                 14042132
# 3                             Closer 2017-01-08                 10948414
# 4                            Starboy 2017-01-08                 10554623
# 5                          More Life 2017-03-18                 11672736
# ...                              ...        ...                      ...
# 1985                    Freaky Deaky 2022-02-25                  6374767
# 1986                   Banking On Me 2022-02-18                 19690109
# 1987                 Numb Little Bug 2022-03-04                 12762392
# 1988   Rocking A Cardigan in Atlanta 2022-03-04                  6792715
# 1989      Bam Bam (feat. Ed Sheeran) 2022-03-04                  5942657
#
# 0      total_streams_2020s  peak_week_streams  2022-03-04  2022-02-25  \
# index
# 1                        0            7309244           0           0
# 2                        0            7745212           0           0
# 3                        0            5528407           0           0
# 4                        0            5329562           0           0
# 5                        0            6461693           0           0
# ...                    ...                ...         ...         ...
# 1985               6374767            6374767           0     6374767
# 1986              19690109            7305777     6245024     6139308
# 1987              12762392            7061002     7061002     5701390
# 1988               6792715            6792715     6792715           0
# 1989               5942657            5942657     5942657           0
#
# 0      2022-02-18  ...  2017-04-28  2017-04-21  2017-04-14  2017-04-07  \
# index              ...
# 1               0  ...           0           0           0     7309244
# 2               0  ...           0           0           0     6296920
# 3               0  ...           0           0           0     5528407
# 4               0  ...           0           0           0     5225061
# 5               0  ...           0           0           0     5211043
# ...           ...  ...         ...         ...         ...         ...
# 1985            0  ...           0           0           0           0
# 1986      7305777  ...           0           0           0           0
# 1987            0  ...           0           0           0           0
# 1988            0  ...           0           0           0           0
# 1989            0  ...           0           0           0           0
#
# 0      2017-03-31     total_2022  total_2021  total_2020  units
# index
# 1               0  0           0           0           0  60910
# 2         7745212  0           0           0           0  64543
# 3         5420007  0           0           0           0  46070
# 4         5329562  0           0           0           0  44413
# 5         6461693  0           0           0           0  53847
# ...           ... ..         ...         ...         ...    ...
# 1985            0  0     6374767           0           0  53123
# 1986            0  0    19690109           0           0  60881
# 1987            0  0    12762392           0           0  58842
# 1988            0  0     6792715           0           0  56606
# 1989            0  0     5942657           0           0  49522
#
# [1989 rows x 269 columns]

# %% [markdown]
# ## Get song URIs from Spotipy

# %% [markdown]
# When searching up a song on Spotify, numerous versions of the same song can be returned. For purposes of this analysis, songs are taken from the explicit version of their parent album/single/EP, regardless of whether the song itself is explicit or clean. If no explicit version of the parent album/single/EP exists, the original version (which would be clean) is to be used.
#
# In order to utilize Spotify's API for the desired songs (from the Google Sheet), URIs must be retrieved using the following functions:

# %%
"""
Returns track URI and explicit status for a song

:param data: a song within the dataframe of all HIT songs (series)
"""

def search_for_URI(data):
    song_to_search = data['title']
    album_to_search = data['album']
    song_and_artist = song_to_search + " " + data['artist']
    
    #this function searches for q on Spotify
    result = sp.search(q=song_and_artist)
    
    #to store all non-instrumental versions of a song
    dct_of_versions = {}
    
    #loops through all results from search
    for song_info_index in range(len(result['tracks']['items'])):

        #checks for results' album to match the input data's album title
        if (result['tracks']['items'][song_info_index]['album']['name'].replace("’","").replace("'","").lower() == album_to_search.replace("’","").replace("'","").lower()):
                        
            #checks for results' song title to match input data's song title
            if (result['tracks']['items'][song_info_index]['name'].replace("’","").replace("'","").lower() == song_to_search.replace("’","").replace("'","").lower()):     
                
                #empty lists of all non-instrumental versions of a song
                explicit_song_list = []
                clean_song_from_original_album_list = []
                clean_song_from_clean_album_list = []

                #if a song isn't explicit
                if result['tracks']['items'][song_info_index]['explicit'] == False:
                    
                    #checks if clean song from original album is not in our dct_of_verions
                    if 'clean_song_from_original_album_list' not in dct_of_versions:
                        clean_song_from_original_album_list.append(result['tracks']['items'][song_info_index]['name'])
                        clean_song_from_original_album_list.append(result['tracks']['items'][song_info_index]['artists'][0]['name'])
                        clean_song_from_original_album_list.append(result['tracks']['items'][song_info_index]['album']['name'])
                        clean_song_from_original_album_list.append(result['tracks']['items'][song_info_index]['explicit'])
                        clean_song_from_original_album_list.append(result['tracks']['items'][song_info_index]['uri'])
                        dct_of_versions['clean_song_from_original_album_list'] = clean_song_from_original_album_list
                        
                    #if clean song from original album is in dct_of_versions
                    else:
                        clean_song_from_clean_album_list.append(result['tracks']['items'][song_info_index]['name'])
                        clean_song_from_clean_album_list.append(result['tracks']['items'][song_info_index]['artists'][0]['name'])
                        clean_song_from_clean_album_list.append(result['tracks']['items'][song_info_index]['album']['name'])
                        clean_song_from_clean_album_list.append(result['tracks']['items'][song_info_index]['explicit'])
                        clean_song_from_clean_album_list.append(result['tracks']['items'][song_info_index]['uri'])
                        dct_of_versions['clean_song_from_clean_album_list'] = clean_song_from_clean_album_list
                        
                #checks if a song is explicit       
                if result['tracks']['items'][song_info_index]['explicit'] == True:
                        
                    explicit_song_list.append(result['tracks']['items'][song_info_index]['name'])
                    explicit_song_list.append(result['tracks']['items'][song_info_index]['artists'][0]['name'])
                    explicit_song_list.append(result['tracks']['items'][song_info_index]['album']['name'])
                    explicit_song_list.append(result['tracks']['items'][song_info_index]['explicit'])
                    explicit_song_list.append(result['tracks']['items'][song_info_index]['uri'])
                    dct_of_versions['explicit_song_list'] = explicit_song_list
    
    if 'explicit_song_list' in dct_of_versions:
        return dct_of_versions['explicit_song_list']
                        
    elif 'clean_song_from_original_album_list' in dct_of_versions:
        return dct_of_versions['clean_song_from_original_album_list']
    else:
        return [song_to_search,data['artist'],album_to_search,"",""]

# %% [markdown]
# The following code takes a while to perform as it uses the function defined above to look up information for ~2000 songs. To measure performance, a timer feature is utilized.

# %%
#create a list of song info: song title, artist, album, explicit or not, track URI

#start timer
start = time.process_time()

song_list = []
[song_list.append(search_for_URI(df.loc[song_info_index+1,'title':'album'])) for song_info_index in range(len(df.loc[:]))]

#print time
print(time.process_time() - start)
# Out:
# 36.71407999999997
# [['The One',
#   'The Chainsmokers',
#   'Memories...Do Not Open',
#   True,
#   'spotify:track:0wfbD5rAksdXUzRvMfM3x5'],
#  ['Sacrifices',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:0xl1w2q4VLojeXp4JfazPL'],
#  ['Closer',
#   'The Chainsmokers',
#   'Closer',
#   False,
#   'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw'],
#  ['Starboy',
#   'The Weeknd',
#   'Starboy',
#   True,
#   'spotify:track:7MXVkk9YMctZqd1Srtv4MB'],
#  ['Get It Together',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:7y6c07pgjZvtHI9kuMVqk1'],
#  ['I Feel It Coming',
#   'The Weeknd',
#   'Starboy',
#   False,
#   'spotify:track:3dhjNA0jGA8vHBQ1VdD6vV'],
#  ['Break Up Every Night',
#   'The Chainsmokers',
#   'Memories...Do Not Open',
#   True,
#   'spotify:track:6cPyTS0Kk2sc4xQwC93kOg'],
#  ['Cold (feat. Future)',
#   'Maroon 5',
#   'Red Pill Blues (Deluxe)',
#   True,
#   'spotify:track:7gwLQ4tZ5UdZ7qNcDyJ8wr'],
#  ['KMT', 'Drake', 'More Life', True, 'spotify:track:2jTujnt0y344ai1rNOywgr'],
#  ['Ice Melts',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:7bJ4mu7MHa3rHiNyKjOoSl'],
#  ['Do Not Disturb',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:2KvHC9z14GSl4YpkNMX384'],
#  ['Galway Girl',
#   'Ed Sheeran',
#   '÷ (Deluxe)',
#   False,
#   'spotify:track:0afhq8XCExXpqazXczTSve'],
#  ['PRIDE.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:6IZvVAP7VPPnsGX6bvgkqg'],
#  ['BLOOD.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:1n4jwRVXdkK2U34nBDUKKT'],
#  ['FEAR.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:23luOrEVHMfoX0AhfbQuS6'],
#  ['GOD.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:5p3NP9mQblDsVJLdfNZJ3I'],
#  ['DUCKWORTH.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:0y9uTzK9cNKSAEHnpeRG8C'],
#  ['Paris',
#   'The Chainsmokers',
#   'Memories...Do Not Open',
#   False,
#   'spotify:track:72jbDTw1piOOj770jWNeaG'],
#  ['Blem', 'Drake', 'More Life', False, 'spotify:track:2XlHu0HcujBCkWMdIAvrqt'],
#  ['Selfish (feat. Rihanna)',
#   'Future',
#   'HNDRXX',
#   True,
#   'spotify:track:6yHkPtl6UQ7RjtJLBPzbJw'],
#  ['Free Smoke',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:05KOgYg8PGeJyyWBPi5ja8'],
#  ['Teenage Fever',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:6n3HGiq4v35D6eFOSwqYuo'],
#  ['Rolex',
#   'Ayo & Teo',
#   'Rolex',
#   False,
#   'spotify:track:0pSBuHjILhNEo55xK1zrRt'],
#  ['HUMBLE.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:7KXjTSCq5nL1LoYtL7XAwS'],
#  ["I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne)",
#   'DJ Khaled',
#   'Grateful',
#   True,
#   'spotify:track:1jYiIOC5d6soxkJP81fxq2'],
#  ['Despacito',
#   'Luis Fonsi',
#   'VIDA',
#   False,
#   'spotify:track:6habFhsOp2NvshLv26DqMb'],
#  ['XO Tour Llif3',
#   'Lil Uzi Vert',
#   'Luv Is Rage 2',
#   True,
#   'spotify:track:7GX5flRQZVHRAGd6B4TmDO'],
#  ['DNA.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:6HZILIRieu8S0iqY8kIKhj'],
#  ['Mask Off',
#   'Future',
#   'FUTURE',
#   True,
#   'spotify:track:0VgkVdmE4gld66l8iyGjgx'],
#  ['LOVE. FEAT. ZACARI.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:6PGoSes0D9eUDeeAafB2As'],
#  ['1-800-273-8255',
#   'Logic',
#   'Everybody',
#   True,
#   'spotify:track:5tz69p7tJuGPeMGwNTxYuV'],
#  ["That's What I Like",
#   'Bruno Mars',
#   '24K Magic',
#   False,
#   'spotify:track:0KKkJNfGyhkQ5aFogxQAPU'],
#  ['Congratulations',
#   'Post Malone',
#   'Stoney (Deluxe)',
#   True,
#   'spotify:track:3a1lNhkSLSkpJE4MSHpDu9'],
#  ['iSpy (feat. Lil Yachty)',
#   'KYLE',
#   'Light of Mine',
#   True,
#   'spotify:track:6xbraxG0bSBOuAr5IUXmtM'],
#  ['ELEMENT.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:1EaKU4dMbesXXd3BrLCtYG'],
#  ['Passionfruit',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:5mCPDVBb16L4XQwDdbRUpz'],
#  ['Unforgettable',
#   'French Montana',
#   'Jungle Rules',
#   True,
#   'spotify:track:3B54sVLJ402zGa6Xm4YGNe'],
#  ['LOYALTY. FEAT. RIHANNA.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:6SwRhMLwNqEi6alNPVG00n'],
#  ['Shape of You',
#   'Ed Sheeran',
#   '÷ (Deluxe)',
#   False,
#   'spotify:track:7qiZfU4dY1lWllzX7mPBI3'],
#  ['Location',
#   'Khalid',
#   'American Teen',
#   False,
#   'spotify:track:152lZdxL1OR0ZMW6KquMif'],
#  ['Portland',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:2bjwRfXMk4uRgOD9IBYl9h'],
#  ['Tunnel Vision',
#   'Kodak Black',
#   'Painting Pictures',
#   True,
#   'spotify:track:4Q3N4Ct4zCuIHuZ65E3BD4'],
#  ['Something Just Like This',
#   'The Chainsmokers',
#   'Memories...Do Not Open',
#   False,
#   'spotify:track:6RUKPb4LETWmmr3iAEQktW'],
#  ['Stay', 'Zedd', 'Stay', False, 'spotify:track:6uBhi9gBXWjanegOb2Phh0'],
#  ['Issues',
#   'Julia Michaels',
#   'Nervous System',
#   False,
#   'spotify:track:7vu0JkJh0ldukEYbTVcqd0'],
#  ['Everybody',
#   'Logic',
#   'Everybody',
#   True,
#   'spotify:track:51sVgPeBHYwbeM1cWegVqR'],
#  ['Slide (feat. Frank Ocean & Migos)',
#   'Calvin Harris',
#   'Funk Wav Bounces Vol.1',
#   True,
#   'spotify:track:7tr2za8SQg2CI8EDgrdtNl'],
#  ['goosebumps',
#   'Travis Scott',
#   'Birds In The Trap Sing McKnight',
#   True,
#   'spotify:track:6gBFPUFcJLzWGx4lenP6h2'],
#  ["It Ain't Me",
#   'Katalina Michelle',
#   "It Ain't Me",
#   False,
#   'spotify:track:2nopcmTVtOhNsO89c4lweL'],
#  ['Magnolia',
#   'Playboi Carti',
#   'Playboi Carti',
#   True,
#   'spotify:track:1e1JKLEDKP7hEQzJfNAgPl'],
#  ['T-Shirt', 'Migos', 'Culture', True, 'spotify:track:7KOlJ92bu51cltsD9KU5I7'],
#  ['Body Like A Back Road',
#   'Sam Hunt',
#   'SOUTHSIDE',
#   False,
#   'spotify:track:7FpBQ067pHB67deawpbbcY'],
#  ['Bad and Boujee (feat. Lil Uzi Vert)',
#   'Migos',
#   'Culture',
#   True,
#   'spotify:track:4Km5HrUvYTaSUfiSGPJeQR'],
#  ['Drowning (feat. Kodak Black)',
#   'A Boogie Wit da Hoodie',
#   'The Bigger Artist',
#   True,
#   'spotify:track:1f5cbQtDrykjarZVrShaDI'],
#  ['XXX. FEAT. U2.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:4iYRa2btalAzPZoSYfROqF'],
#  ['Gyalchester',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:6UjfByV1lDLW0SOVQA4NAi'],
#  ['YAH.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:4BHSjbYylfOH5WAGusDyni'],
#  ['Slippery (feat. Gucci Mane)',
#   'Migos',
#   'Culture',
#   True,
#   'spotify:track:6p8NuHm8uCGnn2Dtbtf7zE'],
#  ['Now Or Never',
#   'Halsey',
#   'hopeless fountain kingdom (Deluxe)',
#   False,
#   'spotify:track:7i2DJ88J7jQ8K7zqFX2fW8'],
#  ['Both (feat. Drake)',
#   'Gucci Mane',
#   'The Return of East Atlanta Santa',
#   True,
#   'spotify:track:5tFep7dXGd7vEJ668wTPux'],
#  ['Bounce Back',
#   'Big Sean',
#   'I Decided.',
#   True,
#   'spotify:track:0SGkqnVQo9KPytSri1H6cF'],
#  ['Swang',
#   'Rae Sremmurd',
#   'SremmLife 2 (Deluxe)',
#   True,
#   'spotify:track:6mapJIPnQ23RTAevUoE0DL'],
#  ['Look At Me!',
#   'XXXTENTACION',
#   'Look At Me!',
#   True,
#   'spotify:track:7floNISpH8VF4z4459Qo18'],
#  ['Sign of the Times',
#   'Harry Styles',
#   'Harry Styles',
#   False,
#   'spotify:track:5Ohxk2dO5COHF1krpoPigN'],
#  ["There's Nothing Holdin' Me Back",
#   'Shawn Mendes',
#   'Illuminate (Deluxe)',
#   False,
#   'spotify:track:7JJmb5XwzOO8jgpou264Ml'],
#  ['wokeuplikethis*',
#   'Playboi Carti',
#   'Playboi Carti',
#   True,
#   'spotify:track:59J5nzL1KniFHnU120dQzt'],
#  ['Redbone',
#   'Childish Gambino',
#   '"Awaken, My Love!"',
#   True,
#   'spotify:track:0wXuerDYiBnERgIpbb3JBR'],
#  ['Fake Love',
#   'Drake',
#   'More Life',
#   True,
#   'spotify:track:343YBumqHu19cGoGARUTsd'],
#  ["Say You Won't Let Go",
#   'James Arthur',
#   'Back from the Edge',
#   False,
#   'spotify:track:5uCax9HTNlzGybIStD3vDh'],
#  ['Killing Spree',
#   'Logic',
#   'Everybody',
#   True,
#   'spotify:track:6OQea06z3cbOqYgG2O6eOZ'],
#  ['Attention',
#   'Charlie Puth',
#   'Voicenotes',
#   False,
#   'spotify:track:5cF0dROlMOK5uNZtivgu50'],
#  ['LUST.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:06FCvd7rrRcF3DdvWH5Isp'],
#  ['FEEL.',
#   'Kendrick Lamar',
#   'DAMN.',
#   True,
#   'spotify:track:2LTlO3NuNVN70lp2ZbVswF'],
#  ['Malibu',
#   'Miley Cyrus',
#   'Younger Now',
#   False,
#   'spotify:track:1UZOjK1BwmwWU14Erba9CZ'],
#  ['Rollin (feat. Future & Khalid)',
#   'Calvin Harris',
#   'Funk Wav Bounces Vol.1',
#   True,
#   'spotify:track:0lMbuWUpfTWhEmOKxppEau'],
#  ['Sweet Creature',
#   'Harry Styles',
#   'Harry Styles',
#   False,
#   'spotify:track:5kRPPEWFJIMox5qIkQkiz5'],
#  ['Bad Liar',
#   'Selena Gomez',
#   'Bad Liar',
#   False,
#   'spotify:track:2fZQIJew3nkNe99s2PKzul'],
#  ['Strip That Down (feat. Quavo)',
#   'Liam Payne',
#   'LP1',
#   False,
#   'spotify:track:29JrmE89KgRyCxBIzq2Ocw'],
#  ['Crying in the Club',
#   'Camila Cabello',
#   'Crying in the Club',
#   False,
#   'spotify:track:1SJtlNRJDeYHioymcvsqev'],
#  ['Thunder',
#   'Imagine Dragons',
#   'Evolve',
#   False,
#   'spotify:track:1zB4vmk8tFRmM9UULNzbLB'],
#  ['Slow Hands',
#   'Niall Horan',
#   'Flicker (Deluxe)',
#   False,
#   'spotify:track:2cOUlop2ZakjOKe4WinesN'],
#  ["Don't Get Too High",
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:0OVhQZkNe7lh0fQeH96EFW'],
#  ['Self-Made',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:2rUwQj4SWaP2anuGDtNpYR'],
#  ['No Longer Friends',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:4IdAIZRVkwuQQnHpi529cn'],
#  ['Run Me Dry',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:5GG3knKdxKWrNboRijxeKF'],
#  ['Blowing Smoke',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:4B2OmQGLBVB51aYNgUvXeM'],
#  ['BUTTERFLY EFFECT',
#   'Travis Scott',
#   'ASTROWORLD',
#   False,
#   'spotify:track:2cYqizR4lgvp4Qu6IQ3qGN'],
#  ['We Both Know',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:3tuyK9qfen7lPMji9Saw3d'],
#  ['You Got It',
#   'Bryson Tiller',
#   'True to Self',
#   False,
#   'spotify:track:5xGH4fqJwvMynXn3dcmbpr'],
#  ['Somethin Tells Me',
#   'Bryson Tiller',
#   'True to Self',
#   True,
#   'spotify:track:3Jrs7cC2OJNlNSy9VnDOMZ'],
#  ['Rain On Me (Intro)',
#   'Bryson Tiller',
#   'True to Self',
#   False,
#   'spotify:track:52LjL3x9tNh6C4eI6SMceX'],
#  ['Down (feat. Gucci Mane)',
#   'Fifth Harmony',
#   'Fifth Harmony',
#   False,
#   'spotify:track:0XQHz5C8PknyrEhyrKxVKa'],
#  ["It's A Vibe",
#   '2 Chainz',
#   'Pretty Girls Like Trap Music',
#   True,
#   'spotify:track:6H0AwSQ20mo62jGlPGB8S6'],
#  ['Know No Better',
#   'Major Lazer',
#   'Know No Better',
#   False,
#   'spotify:track:6BKeNWeUqxmvQ09Gxd3ZGX'],
#  ['Strangers',
#   'Halsey',
#   'hopeless fountain kingdom (Deluxe)',
#   False,
#   'spotify:track:11EDhDAVDtGPoSar6ootYA'],
#  ['Swalla (feat. Nicki Minaj & Ty Dolla $ign)',
#   'Jason Derulo',
#   'Swalla (feat. Nicki Minaj & Ty Dolla $ign)',
#   True,
#   'spotify:track:6kex4EBAj0WHXDKZMEJaaF'],
#  ['2U', 'David Guetta', '2U', False, 'spotify:track:762UXiwEHYY97VL45sAUPR'],
#  ['To the Max (feat. Drake)',
#   'DJ Khaled',
#   'Grateful',
#   True,
#   'spotify:track:2of5xn0GU0TdFneR1saRLH'],
#  ['Love Galore (feat. Travis Scott)',
#   'SZA',
#   'Ctrl',
#   True,
#   'spotify:track:0q75NwOoFiARAVp4EXU4Bs'],
#  ['4 AM',
#   '2 Chainz',
#   'Pretty Girls Like Trap Music',
#   True,
#   'spotify:track:1nX9KhK3Fff27SnrIor2Yb'],
#  ['Believer',
#   'Imagine Dragons',
#   'Evolve',
#   False,
#   'spotify:track:0pqnGHJpmpxLKifKRmU6WP'],
#  ['Doves In The Wind (feat. Kendrick Lamar)',
#   'SZA',
#   'Ctrl',
#   True,
#   'spotify:track:593W4qZOwwdqF6YnimJjL6'],
#  ['Wild Thoughts (feat. Rihanna & Bryson Tiller)',
#   'DJ Khaled',
#   'Grateful',
#   True,
#   'spotify:track:45XhKYRRkyeqoW3teSOkCM'],
#  ['Feels (feat. Pharrell Williams, Katy Perry & Big Sean)',
#   'Calvin Harris',
#   'Funk Wav Bounces Vol.1',
#   True,
#   'spotify:track:5bcTCxgc7xVfSaMV3RuVke'],
#  ['Good Drank',
#   '2 Chainz',
#   'Pretty Girls Like Trap Music',
#   True,
#   'spotify:track:39pS70eeDvyCAF3t8NAlVV'],
#  ['First Day Out',
#   'Tee Grizzley',
#   'My Moment',
#   True,
#   'spotify:track:3muBQDekYAg7jm6hDu6R0Z'],
#  ['Signs', 'Drake', 'Signs', False, 'spotify:track:6Na5uKk5SsqZimk0hAWo8y'],
#  ['No Complaints (feat. Offset & Drake) (Bonus)',
#   'Metro Boomin',
#   'NOT ALL HEROES WEAR CAPES (Deluxe)',
#   True,
#   'spotify:track:156LzfvMNKuXuiot4uzhGD'],
#  ["Don't Quit (feat. Travis Scott & Jeremih)",
#   'DJ Khaled',
#   'Grateful',
#   True,
#   'spotify:track:6LOCAhFzZiavHcLJucLuDy'],
#  ['On Everything (feat. Travis Scott, Rick Ross & Big Sean)',
#   'DJ Khaled',
#   'Grateful',
#   True,
#   'spotify:track:7lxZbmtC6SkUc2yXBgDOdO'],
#  ['Crew (feat. Brent Faiyaz & Shy Glizzy)',
#   'GoldLink',
#   'At What Cost',
#   True,
#   'spotify:track:15EPc80XuFrb2LmOzGjuRg'],
#  ['The Story of O.J.',
#   'JAY-Z',
#   '4:44',
#   True,
#   'spotify:track:6JpN5w95em8SODPiM7W2PH'],
#  ['4:44', 'JAY-Z', '4:44', True, 'spotify:track:1gT5TGwbkkkUliNzHRIGi1'],
#  ['Bank Account',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:2fQrGHiQOvpL9UgPvtYy6G'],
#  ['Kill Jay Z', 'JAY-Z', '4:44', True, 'spotify:track:2kh78Yka2tkYOx3XF9DVpu'],
#  ['Family Feud',
#   'JAY-Z',
#   '4:44',
#   True,
#   'spotify:track:6ku4gCfjdxmYpajNONAciN'],
#  ['Famous',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:6g0TAJ1grweRwBMLQyiZFb'],
#  ['Praying',
#   'Kesha',
#   'Rainbow',
#   False,
#   'spotify:track:0jdny0dhgjUwoIp5GkqEaA'],
#  ['Bam', 'JAY-Z', '4:44', True, 'spotify:track:6Iuh3vNjpWhSeHM3RZgzQL'],
#  ['Caught Their Eyes',
#   'JAY-Z',
#   '4:44',
#   True,
#   'spotify:track:71oM9w2BbJxzTpxzWIE0lw'],
#  ['Marcy Me', 'JAY-Z', '4:44', True, 'spotify:track:5oynsOy80DnodTslgaj3cr'],
#  ['Close My Eyes',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:1mxC48728CxBA7WdKw6nFB'],
#  ['Bad Business',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:5ZIZgRrrDj60O0F5oA9bVz'],
#  ['Numb',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:1vc2YF7ZvUtwr45HNpdGch'],
#  ['Baby Girl',
#   '21 Savage',
#   'Issa Album',
#   True,
#   'spotify:track:3rBwHfVPzmfR3ZVSliB0Om'],
#  ['Fetish (feat. Gucci Mane)',
#   'Selena Gomez',
#   'Fetish (feat. Gucci Mane)',
#   False,
#   'spotify:track:4lnAN2S1fcI0SjxEbksZVr'],
#  ['Sorry Not Sorry',
#   'Demi Lovato',
#   'Tell Me You Love Me',
#   True,
#   'spotify:track:0yvPEnB032fojLfVluFjUv'],
#  ['Mi Gente',
#   'J Balvin',
#   'Vibras',
#   False,
#   'spotify:track:7COfe3P7KgfwDwIRB8LIDw'],
#  ['A Lie',
#   'French Montana',
#   'Jungle Rules',
#   True,
#   'spotify:track:1vVNlXi8gf8tZ7OhnEs4VE'],
#  ['Young Dumb & Broke',
#   'Khalid',
#   'American Teen',
#   False,
#   'spotify:track:5Z3GHaZ6ec9bsiI5BenrbY'],
#  ['Wins & Losses',
#   'Meek Mill',
#   'Wins & Losses',
#   True,
#   'spotify:track:2sBHQfX9QxJwGcdutAj6Pj'],
#  ['Issues',
#   'Meek Mill',
#   'Wins & Losses',
#   True,
#   'spotify:track:1GOuHB20lqVyxv3GdxovPY'],
#  ['In the End',
#   'Linkin Park',
#   'Hybrid Theory (Bonus Edition)',
#   False,
#   'spotify:track:60a0Rd6pjrkxjPbaKzXjfq'],
#  ['1942 Flows',
#   'Meek Mill',
#   'Wins & Losses',
#   True,
#   'spotify:track:7sLDnUauivS2vN6Z9EfUJT'],
#  ['Whatever You Need (feat. Chris Brown & Ty Dolla $ign)',
#   'Meek Mill',
#   'Wins & Losses',
#   True,
#   'spotify:track:6yMxfx9wpiuhhdb8vHDVMu'],
#  ['See You Again (feat. Kali Uchis)',
#   'Tyler, The Creator',
#   'Flower Boy',
#   True,
#   'spotify:track:7KA4W4McWYRpgf0fWsJZWB'],
#  ['Who Dat Boy (feat. A$AP Rocky)',
#   'Tyler, The Creator',
#   'Flower Boy',
#   True,
#   'spotify:track:21yRtB6B8EMounImAfHRCP'],
#  ['Bodak Yellow',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:6KBYefIoo7KydImq1uUQlL'],
#  ['Numb',
#   'Linkin Park',
#   'Meteora',
#   False,
#   'spotify:track:2nLtzopw4rPReszdYBJU6h'],
#  ['Heavy Heart',
#   'Meek Mill',
#   'Wins & Losses',
#   True,
#   'spotify:track:1CGP5ioAXECjvTJdMTvX0O'],
#  ['Heavy (feat. Kiiara)',
#   'Linkin Park',
#   'One More Light',
#   True,
#   'spotify:track:104buTcnP2AsxqB7U1FIZ4'],
#  ['Back to You (feat. Bebe Rexha & Digital Farm Animals)',
#   'Louis Tomlinson',
#   'Back to You (feat. Bebe Rexha & Digital Farm Animals)',
#   True,
#   'spotify:track:7F9vK8hNFMml4GtHsaXui6'],
#  ['Rake It Up (feat. Nicki Minaj)',
#   'Yo Gotti',
#   'I Still Am',
#   True,
#   'spotify:track:4knL4iPxPOZjQzTUlELGSY'],
#  ['Feel It Still',
#   'Portugal. The Man',
#   'Woodstock',
#   False,
#   'spotify:track:6QgjcU0zLnzq5OrUoSZ3OK'],
#  ['Perplexing Pegasus - From SR3MM',
#   'Rae Sremmurd',
#   'SR3MM',
#   True,
#   'spotify:track:1ung2kajpw24AaHjBtPY3j'],
#  ['Reminder',
#   'The Weeknd',
#   'Starboy',
#   True,
#   'spotify:track:37F0uwRSrdzkBiuj0D5UHI'],
#  ['do re mi',
#   'blackbear',
#   'digital druglord',
#   True,
#   'spotify:track:6Se3x9ANMLv0dCDsjGmEjh'],
#  ['Silence',
#   'Marshmello',
#   'Silence',
#   False,
#   'spotify:track:7vGuf3Y35N4wmASOKLUVVU'],
#  ['Friends (with BloodPop®)',
#   'Justin Bieber',
#   'Friends (with BloodPop®)',
#   False,
#   'spotify:track:7iNIg7XDEaYECfWD5dJ9Va'],
#  ['Roll in Peace (feat. XXXTENTACION)',
#   'Kodak Black',
#   'Project Baby 2: All Grown Up (Deluxe Edition)',
#   True,
#   'spotify:track:2L8fevaAigB9yXn5psMR3R'],
#  ['Havana (feat. Young Thug)',
#   'Camila Cabello',
#   'Camila',
#   False,
#   'spotify:track:1rfofaqEpACxVEHIZBJe6W'],
#  ['The Race',
#   'Tay-K',
#   '#SantanaWorld (+)',
#   True,
#   'spotify:track:3wGXyJGsCf1myH5MooQIqE'],
#  ['I Get the Bag (feat. Migos)',
#   'Gucci Mane',
#   'Mr. Davis',
#   True,
#   'spotify:track:1XRgIKC5TPwo7nWGyKqgG0'],
#  ['Look What You Made Me Do',
#   'Taylor Swift',
#   'reputation',
#   False,
#   'spotify:track:1P17dC1amhFzptugyAO7Il'],
#  ['Revenge',
#   'XXXTENTACION',
#   '17',
#   True,
#   'spotify:track:5TXDeTFVRVY7Cvt0Dw4vWW'],
#  ['New Rules',
#   'Dua Lipa',
#   'Dua Lipa (Complete Edition)',
#   False,
#   'spotify:track:43oK4OAWUsRZUDVeHtKI4U'],
#  ["Transportin'",
#   'Kodak Black',
#   'Project Baby 2: All Grown Up (Deluxe Edition)',
#   True,
#   'spotify:track:6ymhLMzUUvjCjreTqVHzsV'],
#  ['The Weekend', 'SZA', 'Ctrl', True, 'spotify:track:6gU9OKjOE7ghfEd55oRO57'],
#  ['Jocelyn Flores',
#   'XXXTENTACION',
#   '17',
#   True,
#   'spotify:track:7m9OqQk4RVRkw9JJdeAw96'],
#  ['...Ready For It?',
#   'Taylor Swift',
#   'reputation',
#   False,
#   'spotify:track:2yLa0QULdQr0qAIvVwN6B5'],
#  ['Fuck Love (feat. Trippie Redd)',
#   'XXXTENTACION',
#   '17',
#   True,
#   'spotify:track:7AQim7LbvFVZJE3O8TYgf2'],
#  ['Sauce It Up',
#   'Lil Uzi Vert',
#   'Luv Is Rage 2',
#   True,
#   'spotify:track:1uL78kFWxhz3umTMWJu8n5'],
#  ['Everybody Dies In Their Nightmares',
#   'XXXTENTACION',
#   '17',
#   True,
#   'spotify:track:3GVkPk8mqxz0itaAriG1L7'],
#  ['The Way Life Goes (feat. Oh Wonder)',
#   'Lil Uzi Vert',
#   'Luv Is Rage 2',
#   True,
#   'spotify:track:2eAZfqOm4EnOF9VvN50Tyc'],
#  ['What Lovers Do (feat. SZA)',
#   'Maroon 5',
#   'Red Pill Blues (Deluxe)',
#   False,
#   'spotify:track:2j5hsQvApottzvTn4pFJWF'],
#  ['444+222',
#   'Lil Uzi Vert',
#   'Luv Is Rage 2',
#   True,
#   'spotify:track:1QgTBfRN5m81a5K01qens6'],
#  ['X',
#   'Lil Uzi Vert',
#   'Luv Is Rage 2',
#   True,
#   'spotify:track:5tRmoZRoupvMYPV1oezFrH'],
#  ['Too Good At Goodbyes',
#   'Sam Smith',
#   'The Thrill Of It All (Special Edition)',
#   False,
#   'spotify:track:3VlbOrM6nYPprVvzBZllE5'],
#  ['Dusk Till Dawn (feat. Sia) - Radio Edit',
#   'ZAYN',
#   'Icarus Falls',
#   False,
#   'spotify:track:3e7sxremeOE3wTySiOhGiP'],
#  ['Unforgettable',
#   'Thomas Rhett',
#   'Life Changes',
#   False,
#   'spotify:track:30MM5jWpUmOxtTNd9Ey5LZ'],
#  ['rockstar (feat. 21 Savage)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:0e7ipj03S05BNilyu5bRzt'],
#  ['Homemade Dynamite',
#   'Lorde',
#   'Melodrama',
#   True,
#   'spotify:track:02oAUzv4M0ItuTDy2RT3IT'],
#  ['DNA',
#   'BTS',
#   "Love Yourself 承 'Her'",
#   False,
#   'spotify:track:3uRLwBjI2TahxslcMTvpFs'],
#  ['Glorious (feat. Skylar Grey)',
#   'Macklemore',
#   'GEMINI',
#   True,
#   'spotify:track:0CokSRCu5hZgPxcZBaEzVE'],
#  ['I Fall Apart',
#   'Post Malone',
#   'Stoney (Deluxe)',
#   True,
#   'spotify:track:75ZvA4QfFiZvzhj2xkaWAh'],
#  ['Gucci Gang',
#   'Lil Pump',
#   'Lil Pump',
#   True,
#   'spotify:track:43ZyHQITOjhciSUUNPVRHc'],
#  ["Say A'",
#   'A Boogie Wit da Hoodie',
#   'The Bigger Artist',
#   True,
#   'spotify:track:3AMnOVxEHUgVrythGgqPhI'],
#  ['No Promises',
#   'A Boogie Wit da Hoodie',
#   'The Bigger Artist',
#   True,
#   'spotify:track:2BJpuAoDeQ1QuPvnryfAWK'],
#  ['Beast Mode (feat. PnB Rock & YoungBoy Never Broke Again)',
#   'A Boogie Wit da Hoodie',
#   'The Bigger Artist',
#   True,
#   'spotify:track:1AH60dMaEfNjzDoUIFwIQi'],
#  ['No Limit',
#   'G-Eazy',
#   'The Beautiful & Damned',
#   True,
#   'spotify:track:2DQ1ITjI0YoLFzuADN1ZBW'],
#  ['Plain Jane REMIX (feat. Nicki Minaj)',
#   'A$AP Ferg',
#   'Plain Jane REMIX (feat. Nicki Minaj)',
#   True,
#   'spotify:track:2YzmfPLqUx5CJOaw5ThsBV'],
#  ['Perfect',
#   'Ed Sheeran',
#   '÷ (Deluxe)',
#   False,
#   'spotify:track:0tgVpDi06FyKpA1z0VMD4v'],
#  ['Go Flex',
#   'Post Malone',
#   'Stoney (Deluxe)',
#   True,
#   'spotify:track:5yuShbu70mtHXY0yLzCQLQ'],
#  ['Let You Down',
#   'NF',
#   'Perception',
#   False,
#   'spotify:track:52okn5MNA47tk87PeZJLEL'],
#  ['Bad At Love',
#   'Halsey',
#   'hopeless fountain kingdom (Deluxe)',
#   False,
#   'spotify:track:7y9iMe8SOB6z3NoHE2OfXl'],
#  ['What Ifs (feat. Lauren Alaina)',
#   'Kane Brown',
#   'Kane Brown (Deluxe Edition)',
#   False,
#   'spotify:track:7sQJDTH7VfwERzHbUao0TB'],
#  ['Gorgeous',
#   'Taylor Swift',
#   'reputation',
#   False,
#   'spotify:track:1ZY1PqizIl78geGM4xWlEA'],
#  ['Patek Water (feat. Offset)',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:7r6LNJT2LqpLpEyZQJPygt'],
#  ['No Cap',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:06Gyf2pFDVmN5K8XAawG96'],
#  ['Feed Me Dope',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:3lyeSiAIdLoZUHhV8psOTI'],
#  ['All da Smoke',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:1wWRtPIKD7ZNvtsrzLyTev'],
#  ['Three',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:4W598w0KcHVG5Nwqk0qMpj'],
#  ['Cruise Ship',
#   'Young Thug',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:3C4FUqrrjuvWoHwsumWfIu'],
#  ['200',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:5b06JZjts6dgyyuY1m7roq'],
#  ['4 da Gang',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:3IJ6BBFLD2I2CH3hHFQj3O'],
#  ['Drip on Me',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:2ya9d4B06EQ8Fpj5SSqiTH'],
#  ['Killed Before',
#   'Young Thug',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:0jPLBur1qXRfj3pbuJSX03'],
#  ['Real Love',
#   'Future',
#   'SUPER SLIMEY',
#   True,
#   'spotify:track:1OwNWr75pNTyhifOTT0uIG'],
#  ['MotorSport',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:4wFjTWCunQFKtukqrNijEt'],
#  ['Wolves',
#   'Selena Gomez',
#   'Wolves',
#   False,
#   'spotify:track:0tBbt8CrmxbjRP0pueQkyU'],
#  ['Candy Paint',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:32lItqlMi4LBhb4k0BaSaC'],
#  ['Let Me Go (with Alesso, Florida Georgia Line & watt)',
#   'Hailee Steinfeld',
#   'Let Me Go (with Alesso, Florida Georgia Line & watt)',
#   False,
#   'spotify:track:5Gu0PDLN4YJeW75PpBSg9p'],
#  ['Walk On Water (feat. Beyoncé)',
#   'Eminem',
#   'Revival',
#   True,
#   'spotify:track:7CcoUAtUcYhUfBsmtn0ajO'],
#  ['Ric Flair Drip (with Metro Boomin)',
#   'Offset',
#   'Without Warning',
#   True,
#   'spotify:track:7sO5G9EABYOXQKNPNiE9NR'],
#  ['Ghostface Killers (feat. Travis Scott)',
#   '21 Savage',
#   'Without Warning',
#   True,
#   'spotify:track:5u6vkDnOyaf8LsteDAj2ub'],
#  ['Wanted You (feat. Lil Uzi Vert)',
#   'NAV',
#   'RECKLESS',
#   True,
#   'spotify:track:1Faq8G2y56A8fRv7HsLq25'],
#  ['Rap Saved Me (feat. Quavo)',
#   '21 Savage',
#   'Without Warning',
#   True,
#   'spotify:track:0tdCy39PgWN8LFWu34ORn3'],
#  ['Call It What You Want',
#   'Taylor Swift',
#   'reputation',
#   False,
#   'spotify:track:1GwMQaZz6Au3QLDbjbMdme'],
#  ['Meant to Be (feat. Florida Georgia Line)',
#   'Bebe Rexha',
#   'All Your Fault: Pt. 2',
#   False,
#   'spotify:track:7iDa6hUg2VgEL1o1HjmfBn'],
#  ['Codeine Dreaming (feat. Lil Wayne)',
#   'Kodak Black',
#   'Project Baby 2: All Grown Up (Deluxe Edition)',
#   True,
#   'spotify:track:4DTpngLjoHj5gFxEZFeD3J'],
#  ['All I Want for Christmas Is You',
#   'Mariah Carey',
#   'Merry Christmas',
#   False,
#   'spotify:track:0bYg9bo50gSsH3LtXe2SQn'],
#  ['MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   'BTS',
#   'MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   False,
#   'spotify:track:6XxpvCj3eLWs3lYowSgC4G'],
#  ['Betrayed',
#   'Lil Xan',
#   'TOTAL XANARCHY',
#   True,
#   'spotify:track:4vaxvNDaLSoD36iZX515ug'],
#  ["Rockin' Around The Christmas Tree",
#   'Brenda Lee',
#   'Merry Christmas From Brenda Lee',
#   False,
#   'spotify:track:2EjXfH91m7f8HiJN1yQg97'],
#  ['Sky Walker (feat. Travis Scott)',
#   'Miguel',
#   'War & Leisure',
#   True,
#   'spotify:track:5WoaF1B5XIEnWfmb5NZikf'],
#  ['Him & I (with Halsey)',
#   'G-Eazy',
#   'The Beautiful & Damned',
#   True,
#   'spotify:track:5k38wzpLb15YgncyWdTZE4'],
#  ["It's the Most Wonderful Time of the Year",
#   'Andy Williams',
#   'The Andy Williams Christmas Album',
#   False,
#   'spotify:track:5hslUAKq9I9CG2bAulFkHN'],
#  ['GUMMO',
#   '6ix9ine',
#   'Day69: Graduation Day',
#   True,
#   'spotify:track:4HbiCvH1R7mVOJ7KY7JQBD'],
#  ['Bartier Cardi (feat. 21 Savage)',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:0dIoGTQXDh1wVnhIiSyYEa'],
#  ['American Teen',
#   'Khalid',
#   'American Teen',
#   False,
#   'spotify:track:312WNtMs3F28cUukaPY9bo'],
#  ['River (feat. Ed Sheeran)',
#   'Eminem',
#   'Revival',
#   True,
#   'spotify:track:1cS0TgbR263ey9jn0MwD2s'],
#  ['Eye 2 Eye',
#   'Huncho Jack',
#   'Huncho Jack, Jack Huncho',
#   True,
#   'spotify:track:4vwfOiyWxXeEdx4ejAJgdx'],
#  ['Modern Slavery',
#   'Huncho Jack',
#   'Huncho Jack, Jack Huncho',
#   True,
#   'spotify:track:7J6bnDDitOwfelaJNixHhL'],
#  ['Dubai Shit',
#   'Huncho Jack',
#   'Huncho Jack, Jack Huncho',
#   True,
#   'spotify:track:6urLjX35oXXRYtcH1b3dCh'],
#  ['Saint',
#   'Huncho Jack',
#   'Huncho Jack, Jack Huncho',
#   True,
#   'spotify:track:7foypmc7KZyU716Yv63BPe'],
#  ['End Game',
#   'Taylor Swift',
#   'reputation',
#   False,
#   'spotify:track:2x0WlnmfG39ZuDmstl9xfX'],
#  ['Stir Fry',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:2UVbBKQOdFAekPTRsnkzcf'],
#  ['Black & Chinese',
#   'Huncho Jack',
#   'Huncho Jack, Jack Huncho',
#   True,
#   'spotify:track:628Ueb4sRiXApObhcU9iPU'],
#  ['Finesse - Remix; feat. Cardi B',
#   'Bruno Mars',
#   'Finesse (Remix) [feat. Cardi B]',
#   False,
#   'spotify:track:3Vo4wInECJQuz9BIBMOu8i'],
#  ['All The Stars (with SZA)',
#   'Kendrick Lamar',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:3GCdLUSnKSMJhs4Tj6CV3s'],
#  ['Filthy',
#   'Justin Timberlake',
#   'Man of the Woods',
#   False,
#   'spotify:track:5ZpjODX6OH1xZs3AOewTO6'],
#  ['Never Be the Same',
#   'Camila Cabello',
#   'Camila',
#   False,
#   'spotify:track:4eWQlBRaTjPPUlzacqEeoQ'],
#  ['Tell Me You Love Me',
#   'Demi Lovato',
#   'Tell Me You Love Me',
#   False,
#   'spotify:track:21RCuMVSlblTmyYm2DnPCR'],
#  ['PICK IT UP (feat. A$AP Rocky)',
#   'Famous Dex',
#   'Dex Meets Dexter',
#   True,
#   'spotify:track:7KIklhVwuQZA1UuyOFlgEr'],
#  ['Nowadays (feat. Landon Cube)',
#   'Lil Skies',
#   'Life of a Dark Rose',
#   True,
#   'spotify:track:2u7mxWSeoqTXndK5e08jMp'],
#  ['Red Roses (feat. Landon Cube)',
#   'Lil Skies',
#   'Life of a Dark Rose',
#   True,
#   'spotify:track:3ZhTT6yjZwpPph5MIJ53XY'],
#  ['Rewrite The Stars',
#   'Zac Efron',
#   'The Greatest Showman (Original Motion Picture Soundtrack)',
#   False,
#   'spotify:track:65fpYBrI8o2cfrwf2US4gq'],
#  ['My My My!',
#   'Troye Sivan',
#   'Bloom',
#   False,
#   'spotify:track:4NiehSBQthimPzRsVeOgCT'],
#  ["King's Dead (with Kendrick Lamar, Future & James Blake)",
#   'Jay Rock',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:1eLSF6HfrRA0AsNmTkUlKx'],
#  ["God's Plan",
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:6DCZcSspjsKoFjzjrWoCdn'],
#  ['Diplomatic Immunity',
#   'Drake',
#   'Diplomatic Immunity',
#   True,
#   'spotify:track:4haJoBPbPj9QFKNpp9e8kx'],
#  ['KEKE',
#   '6ix9ine',
#   'Day69: Graduation Day',
#   True,
#   'spotify:track:14PlDNjNh3pXyHXzkhX8n5'],
#  ['Mine', 'Bazzi', 'COSMIC', True, 'spotify:track:7uzmGiiJyRfuViKKK3lVmR'],
#  ['This Is Me',
#   'Keala Settle',
#   'The Greatest Showman (Original Motion Picture Soundtrack)',
#   False,
#   'spotify:track:45aBsnKRWUzhwbcqOJLwfe'],
#  ['Walk It Talk It',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:6n4U3TlzUGhdSFbUUhTvLP'],
#  ['Narcos',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:0wbnC9AUenxp613TYaJsGK'],
#  ['BBO (Bad Bitches Only)',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:4BHzHISX21PYwGXiBEUQ70'],
#  ['Notice Me',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:3OnOomd79OjqSYHchCQ6ht'],
#  ['Supastars',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:7yt6eiZQCkVFEzwGp4Pbor'],
#  ['Gang Gang',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:6RKkHI2fkmgZq7uQPPav8f'],
#  ['Emoji A Chain',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:0G9rmRmQDFk9O2tzZLyRkc'],
#  ['Higher We Go - Intro',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:43dOwOq0mB4i6j4SpcSkqC'],
#  ['CC', 'Migos', 'Culture II', True, 'spotify:track:35ffVv9x4mtzBh5rF1K9sP'],
#  ['Too Much Jewelry',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:4loAa1lBkE83qJXU1ddmCV'],
#  ['Too Playa',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:4TAifFqlNkBvrycHbWV9Ew'],
#  ['Crown the Kings',
#   'Migos',
#   'Culture II',
#   True,
#   'spotify:track:2664gDzsUz6oHnSFyfKjcq'],
#  ['Pray For Me (with Kendrick Lamar)',
#   'The Weeknd',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:77UjLW8j5UAGAGVGhR5oUK'],
#  ['The Middle',
#   'Zedd',
#   'The Middle',
#   False,
#   'spotify:track:09IStsImFySgyp0pIQdqAc'],
#  ['Say Something (feat. Chris Stapleton)',
#   'Justin Timberlake',
#   'Man of the Woods',
#   False,
#   'spotify:track:1LhMopPAallLeaeNutqbgS'],
#  ['IDGAF',
#   'Dua Lipa',
#   'Dua Lipa (Complete Edition)',
#   True,
#   'spotify:track:6acdKgBrJoYKbJD6WhG81R'],
#  ['New Freezer (feat. Kendrick Lamar)',
#   'Rich The Kid',
#   'The World Is Yours',
#   True,
#   'spotify:track:2EgB4n6XyBsuNUbuarr4eG'],
#  ['Look Alive (feat. Drake)',
#   'BlocBoy JB',
#   'Simi',
#   True,
#   'spotify:track:6HJ34Zyw6bg8yGm28AxLXf'],
#  ['X (with 2 Chainz & Saudi)',
#   'ScHoolboy Q',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:4LmAnpjlhWTahvRkYR8xJa'],
#  ['The Ways (with Swae Lee)',
#   'Khalid',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:5jyyPsIGM2yqkZN9R3TmvN'],
#  ['Paramedic!',
#   'SOB X RBE',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:2tPcTFiQF9MbVUyjZ3zDhA'],
#  ['Big Shot (with Travis Scott)',
#   'Kendrick Lamar',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:5cXg9IQS34FzLVdHhp7hu7'],
#  ['Black Panther',
#   'Kendrick Lamar',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:5qN4HFkapdAOV94XPryVof'],
#  ['PROUD',
#   '2 Chainz',
#   'The Play Don’t Care Who Makes It',
#   True,
#   'spotify:track:365wwIjijQdlRJEjUWTidq'],
#  ['Opps (with Yugen Blakrok)',
#   'Vince Staples',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:7bUcBztfGqO7cSI2gMZeCI'],
#  ['Plug Walk',
#   'Rich The Kid',
#   'The World Is Yours',
#   True,
#   'spotify:track:1ZAyjvIk9YiD76yYy0TEG6'],
#  ['I Am',
#   'Jorja Smith',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:0DJBgBiYeSn6n1AXAkFVE8'],
#  ['Bloody Waters (with Anderson .Paak & James Blake)',
#   'Ab-Soul',
#   'Black Panther The Album Music From And Inspired By',
#   True,
#   'spotify:track:4KXwFI9pgJLpUIAc9oSL8j'],
#  ['Amorfoda',
#   'Bad Bunny',
#   'Amorfoda',
#   True,
#   'spotify:track:68QcquxCS39cQGTsRrJWIR'],
#  ['Bounce Out With That',
#   'YBN Nahmir',
#   'YBN: The Mixtape',
#   True,
#   'spotify:track:5gQcxYXqnofyocKgEbGYKt'],
#  ['Outside Today',
#   'YoungBoy Never Broke Again',
#   'Until Death Call My Name (Reloaded)',
#   True,
#   'spotify:track:3sA7HKGzcKTVscdiTCrWpX'],
#  ['Psycho (feat. Ty Dolla $ign)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:3swc6WTsr7rl9DqQKQA55C'],
#  ['44 More',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:3e7Y6sfFlIdBMJhX7wpqVO'],
#  ['Love Lies',
#   'Khalid',
#   'Love, Simon (Original Motion Picture Soundtrack)',
#   False,
#   'spotify:track:7w3rcy1CrATkUgCoItTbId'],
#  ['BILLY',
#   '6ix9ine',
#   'Day69: Graduation Day',
#   True,
#   'spotify:track:5KhFaq45chTw8RGfWo8T8J'],
#  ['RONDO',
#   '6ix9ine',
#   'Day69: Graduation Day',
#   True,
#   'spotify:track:3p6JF5nt0bZOSgZRONNZp0'],
#  ['SAD!', 'XXXTENTACION', '?', True, 'spotify:track:3ee8Jmje8o58CHK66QrVC2'],
#  ['changes',
#   'XXXTENTACION',
#   '?',
#   False,
#   'spotify:track:7AFASza1mXqntmGtbxXprO'],
#  ['Top Off (feat. JAY Z, Future & Beyoncé)',
#   'DJ Khaled',
#   'Father Of Asahd',
#   True,
#   'spotify:track:0QzliuYF4qRMXI76GwepXq'],
#  ['Everyday',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:4EAV2cKiqKP5UPZmY6dejk'],
#  ['Powerglide (feat. Juicy J) - From SR3MM',
#   'Rae Sremmurd',
#   'SR3MM',
#   True,
#   'spotify:track:1BuZAIO8WZpavWVbbq3Lci'],
#  ['FRIENDS',
#   'Marshmello',
#   'FRIENDS',
#   True,
#   'spotify:track:08bNPGLD8AhKpnnERrAc6G'],
#  ['Contra',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:7u90MSvVyEjL0c8icaE7jl'],
#  ['Overnight',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:3s3VVLE1kB7Xk2AoJKlGmr'],
#  ['Indica Badu',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:0jqBo5RYn008f4ZY8kPewW'],
#  ['Midnight',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:1GtVGc1UYin3zpMUdNSSpM'],
#  ['66',
#   'Lil Yachty',
#   'Lil Boat 2',
#   True,
#   'spotify:track:6tarvNiKnEjYMj1VZhlDqR'],
#  ['Yuck',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:0D5CXSUx8GOCHSY8KWgi9h'],
#  ['BoomTrap Protocol',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:4fZxGiES1FKbNqJPrI4L3s'],
#  ['Wassup',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:5KVciTEfXvpcFHR3RFbtJy'],
#  ['Warm It Up',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:3W4JFzOQdo5J2Wgt9DFg24'],
#  ['Wizard Of Oz',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:2ycWek3FNNVHBhz2TcnOzZ'],
#  ['BOOM!',
#   'Lil Yachty',
#   'Lil Boat 2',
#   True,
#   'spotify:track:2PsZsnqSMXt4oKi0xHVvgF'],
#  ['State Of Emergency',
#   'Logic',
#   'Bobby Tarantino II',
#   True,
#   'spotify:track:58cvckETahSOG74RP5WE99'],
#  ['NBAYOUNGBOAT',
#   'Lil Yachty',
#   'Lil Boat 2',
#   True,
#   'spotify:track:6K2anECyrckidwf5wxS78Q'],
#  ['Moonlight',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:0JP9xo3adEtGSdUEISiszL'],
#  ['Freaky Friday (feat. Chris Brown)',
#   'Lil Dicky',
#   'Freaky Friday (feat. Chris Brown)',
#   True,
#   'spotify:track:10Igtw8bSDyyFs7KIsKngZ'],
#  ['the remedy for a broken heart (why am I so in love)',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:4UKCKdYiLN6IMA5ZESUTL7'],
#  ['NUMB', 'XXXTENTACION', '?', False, 'spotify:track:01TnVDiet1DFTsyWKUKovl'],
#  ['infinity (888) - feat. Joey Bada$$',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:7J2gyNghNTzl4EsLhXp01Q'],
#  ['going down!',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:7CkbRn6S0itJqcqn88AtSV'],
#  ['Hope', 'XXXTENTACION', '?', True, 'spotify:track:2ZRo7axmMPeSVUvDbGkJah'],
#  ['$$$ - with Matt Ox',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:65u1dHQyQyE4y4aN2eDmMF'],
#  ['ALONE, PART 3',
#   'XXXTENTACION',
#   '?',
#   False,
#   'spotify:track:2oe6dDthgthqUkfL3czpEd'],
#  ['Wait',
#   'Maroon 5',
#   'Red Pill Blues (Deluxe)',
#   False,
#   'spotify:track:6AvfZXpbb6r35DfF7gHPRq'],
#  ['Floor 555',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:6r7ULK6c5CLVvImjTIztl1'],
#  ['SMASH! - feat. PnB Rock',
#   'XXXTENTACION',
#   '?',
#   True,
#   'spotify:track:6rAGFgcGtlIdYxlhDizXNo'],
#  ['In My Blood',
#   'Shawn Mendes',
#   'Shawn Mendes (Deluxe)',
#   False,
#   'spotify:track:2SFnIqRWyHt9MUNeXkykii'],
#  ['Lemon',
#   'N.E.R.D',
#   'NO ONE EVER REALLY DIES',
#   True,
#   'spotify:track:4PpuH4mxL0rD35mOWaLoKS'],
#  ['Lost In Japan',
#   'Shawn Mendes',
#   'Shawn Mendes (Deluxe)',
#   False,
#   'spotify:track:0TFpGNlWslRQO4oyTtJq6K'],
#  ['Call Out My Name',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   False,
#   'spotify:track:09mEdoA6zrmBPgTEN5qXmN'],
#  ['Wasted Times',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   True,
#   'spotify:track:7DKS0rX27cCEPsK0R6tFWS'],
#  ['Try Me',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   False,
#   'spotify:track:4ppTAJUbNXELZcoUaL90wo'],
#  ['I Was Never There',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   False,
#   'spotify:track:1cKHdTo9u0ZymJdPGSh6nq'],
#  ['Hurt You',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   True,
#   'spotify:track:6QdnKD1zwEgyOWtkrdzlOF'],
#  ['Privilege',
#   'The Weeknd',
#   'My Dear Melancholy,',
#   True,
#   'spotify:track:0Nwar8rweBUyfyuoyjjUvk'],
#  ['Be Careful',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:2Yl4OmDby9iitgNWZPwxkd'],
#  ['JAPAN',
#   'Famous Dex',
#   'Dex Meets Dexter',
#   True,
#   'spotify:track:2GjPvd90XrBXNtuIzXTqdW'],
#  ['Lost It (feat. Quavo & Offset)',
#   'Rich The Kid',
#   'The World Is Yours',
#   True,
#   'spotify:track:68449VKGwYShObwI2UFdFt'],
#  ['OKRA',
#   'Tyler, The Creator',
#   'OKRA',
#   True,
#   'spotify:track:74ZovzRxHBvCq5yIwe8boh'],
#  ['End Of Discussion (feat. Lil Wayne)',
#   'Rich The Kid',
#   'The World Is Yours',
#   True,
#   'spotify:track:4nSSZHI4FUIiQOJELTTZdS'],
#  ['Pineapple (feat. Gucci Mane & Quavo)',
#   'Ty Dolla $ign',
#   'Beach House 3 (Deluxe Edition)',
#   True,
#   'spotify:track:2R7Gn3cjnPaVO0Oj8nsTDP'],
#  ['Nice For What',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:3CA9pLiwRIGtUBiMjbZmRw'],
#  ['I Like It',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:58q2HKrzhC3ozto2nDdN4z'],
#  ['Drip (feat. Migos)',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:2qcG0nZ6S3zZV0UrkY5nFo'],
#  ['Ring (feat. Kehlani)',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:5DfWF0jqMgZDCiu9zJENTA'],
#  ['Get Up 10',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:7p2ewixAShLpjDZrnzZK7c'],
#  ['I Do (feat. SZA)',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:1f5PNhkNgUpvDEeZfcIlO1'],
#  ['Bickenhead',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:17Yq72h0p15OhCbZ5lJ5gd'],
#  ['Best Life (feat. Chance The Rapper)',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:00B7TZ0Xawar6NZ00JFomN'],
#  ['Thru Your Phone',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:74cVJfmK18rhWnscIpGXjt'],
#  ['Money Bag',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:1vBeIXlzbAieGoDqInav5j'],
#  ['She Bad',
#   'Cardi B',
#   'Invasion of Privacy',
#   True,
#   'spotify:track:0CfmNX2TXk7yoJqHJiixnp'],
#  ['A$AP Forever (feat. Moby)',
#   'A$AP Rocky',
#   'A$AP Forever (feat. Moby)',
#   True,
#   'spotify:track:1YmF9PvLhIISIANoMLIYGq'],
#  ['Bad Company (feat. BlocBoy JB)',
#   'A$AP Rocky',
#   'Bad Company (feat. BlocBoy JB)',
#   True,
#   'spotify:track:3ZYwSDF9knZI0RVlKR4PHC'],
#  ['One Kiss (with Dua Lipa)',
#   'Calvin Harris',
#   'One Kiss (with Dua Lipa)',
#   False,
#   'spotify:track:7ef4DlsgrMEH11cDZd32M6'],
#  ['Chun-Li',
#   'Nicki Minaj',
#   'Queen',
#   True,
#   'spotify:track:0kCakXs4r2adpGE43JXsFg'],
#  ['Barbie Tingz',
#   'Nicki Minaj',
#   'Barbie Tingz',
#   True,
#   'spotify:track:2qsQ8eVDPmobZpvDxQCVQu'],
#  ['Guatemala - From Swaecation',
#   'Rae Sremmurd',
#   'SR3MM',
#   True,
#   'spotify:track:0TCnOEVeLQMXOUrpPlM7uY'],
#  ['KOD', 'J. Cole', 'KOD', True, 'spotify:track:7yotKA30dwTKNEGomV9ZsI'],
#  ['Kevin’s Heart',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:6tZ3b7ik1QDXFAZlXib0YZ'],
#  ['ATM', 'J. Cole', 'KOD', True, 'spotify:track:2UciqgwVDwro0fev3MFbxJ'],
#  ['Photograph',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:0bhnUFDQFCEHCBlsQfHnj5'],
#  ['Motiv8', 'J. Cole', 'KOD', True, 'spotify:track:1AT4xjNarTswd0UZ5FlmKF'],
#  ['1985 - Intro to “The Fall Off”',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:7EulRO07ZgchxqKUHb8Pvc'],
#  ['The Cut Off (feat. kiLL edward)',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:3rFF7kSm5qBOOPs6ljFgPp'],
#  ['BRACKETS', 'J. Cole', 'KOD', True, 'spotify:track:5sWbwccBcyHsg5LEKWGZo9'],
#  ['Window Pain - Outro',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:5Lgqu1th1KqlG97OF2gWGe'],
#  ['FRIENDS (feat. kiLL edward)',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:6onwlDmIVKE8bBgyBRSuS0'],
#  ['Once an Addict - Interlude',
#   'J. Cole',
#   'KOD',
#   True,
#   'spotify:track:0Px86mRlxdB3YqpK6KXWlr'],
#  ['Intro', 'J. Cole', 'KOD', False, 'spotify:track:52Hq1nvCDDZ17dhgGWLnCI'],
#  ['Esskeetit',
#   'Lil Pump',
#   'Harverd Dropout',
#   True,
#   'spotify:track:31gUUwByx4pmnA8KAFkhhH'],
#  ['CLOSE (feat. Travis Scott) - From SR3MM',
#   'Rae Sremmurd',
#   'SR3MM',
#   True,
#   'spotify:track:1oUudyBYVGMIC8JXeIsFzq'],
#  ['Better Now',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:7dt6x5M1jzdTEt8oCbisTK'],
#  ['Paranoid',
#   'Post Malone',
#   'beerbongs & bentleys',
#   False,
#   'spotify:track:3fpVWegR6YOS1Yk5HSMYIq'],
#  ['Rich & Sad',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:2VdT56BGpdqNHUgOe1j5vc'],
#  ['Spoil My Night (feat. Swae Lee)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:5VuxWXbt7XENQCtE9TzpTv'],
#  ['Stay',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:4H7WNRErSbONkM06blBoGc'],
#  ['Ball For Me (feat. Nicki Minaj)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:6IaieqiCVvsNvEt6Y7yOFa'],
#  ['Zack And Codeine',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:5lZZmityu9TAjNvSY6GLhR'],
#  ['Over Now',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:09IOPhEh1OMe0HD9b36FJk'],
#  ["Takin' Shots",
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:5ffntNJnJOeFv7b7DCd0Bw'],
#  ['Same Bitches (feat. G-Eazy & YG)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:688QpQAwqsLdBR6lr13wK1'],
#  ['92 Explorer',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:1D2L6MefbXon28PzIk9I3r'],
#  ['Otherside',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:4qWCFTuNnmGNdY4egtb4ZY'],
#  ['Blame It On Me',
#   'Post Malone',
#   'beerbongs & bentleys',
#   False,
#   'spotify:track:1ZemPoaj7LBj1RAQrb89EC'],
#  ['Sugar Wraith',
#   'Post Malone',
#   'beerbongs & bentleys',
#   True,
#   'spotify:track:0MrRAUcB8AZiB9ue2VOBYe'],
#  ['no tears left to cry',
#   'Ariana Grande',
#   'Sweetener',
#   False,
#   'spotify:track:2qT1uLXPVPzGgFOx4jtEuo'],
#  ['Jonestown (Interlude)',
#   'Post Malone',
#   'beerbongs & bentleys',
#   False,
#   'spotify:track:0R6Jlsq25eZB3Wftpxi3oF'],
#  ['OTW', 'Khalid', 'OTW', True, 'spotify:track:6Hgh47WXVKtXN5zGOu0hjI'],
#  ['Watch (feat. Lil Uzi Vert & Kanye West)',
#   'Travis Scott',
#   'Watch (feat. Lil Uzi Vert & Kanye West)',
#   True,
#   'spotify:track:3DoBTwfr8yi2LN08SBpFkN'],
#  ['This Is America',
#   'Childish Gambino',
#   'This Is America',
#   True,
#   'spotify:track:0b9oOr2ZgvyQu88wzixux9'],
#  ['Shoota (feat. Lil Uzi Vert)',
#   'Playboi Carti',
#   'Die Lit',
#   True,
#   'spotify:track:2BJSMvOGABRxokHKB0OI8i'],
#  ['Yes Indeed',
#   'Lil Baby',
#   'Harder Than Ever',
#   True,
#   'spotify:track:6vN77lE9LK6HP2DewaN6HZ'],
#  ["Boo'd Up",
#   'Ella Mai',
#   'Ella Mai',
#   False,
#   'spotify:track:4squZv12LD9M8ooJfoVgZS'],
#  ['Heaven',
#   'Kane Brown',
#   'Kane Brown (Deluxe Edition)',
#   False,
#   'spotify:track:1HXy5I3HTWq8OvxCn0z7G7'],
#  ['Lucid Dreams',
#   'Juice WRLD',
#   'Goodbye & Good Riddance',
#   True,
#   'spotify:track:285pBltuF7vW8TeWk8hdRR'],
#  ['FAKE LOVE',
#   'BTS',
#   "Love Yourself 轉 'Tear'",
#   False,
#   'spotify:track:6m1TWFMeon7ai9XLOzdbiR'],
#  ['Champion (feat. Travis Scott)',
#   'NAV',
#   'RECKLESS',
#   True,
#   'spotify:track:6nO3tr47nr2P7f3hXb8JIo'],
#  ['All Girls Are The Same',
#   'Juice WRLD',
#   'Goodbye & Good Riddance',
#   True,
#   'spotify:track:4VXIryQMWpIdGgYR4TrjT1'],
#  ['Life Goes On',
#   'Lil Baby',
#   'Harder Than Ever',
#   True,
#   'spotify:track:2bSk87AVkCIIC3Bcligq1z'],
#  ['Change Lanes',
#   'Kevin Gates',
#   'Chained to the City',
#   True,
#   'spotify:track:59XHPyb0MTMElZpkG0Wp69'],
#  ['Te Boté - Remix',
#   'Nio Garcia',
#   'Now Or Never',
#   True,
#   'spotify:track:3X5M53Xi5k1SijRtZMM3TA'],
#  ["I'm Upset",
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:3qN5qMTKyEEmiTZD38BNTT'],
#  ['Praise The Lord (Da Shine) (feat. Skepta)',
#   'A$AP Rocky',
#   'TESTING',
#   True,
#   'spotify:track:7ycWLEP1GsNjVvcjawXz3z'],
#  ['If You Know You Know',
#   'Pusha T',
#   'DAYTONA',
#   True,
#   'spotify:track:6bGwKHXHNLmTy6yt147FPh'],
#  ['What Would Meek Do?',
#   'Pusha T',
#   'DAYTONA',
#   True,
#   'spotify:track:5vnuJ8EopkP5dHukpOmT3L'],
#  ['Tony Tone',
#   'A$AP Rocky',
#   'TESTING',
#   True,
#   'spotify:track:52eYVUkFTOVozbVFIaFrnV'],
#  ['Fukk Sleep (feat. FKA twigs)',
#   'A$AP Rocky',
#   'TESTING',
#   True,
#   'spotify:track:1AqemxWsT0iGg5Lvkm16Bt'],
#  ['All Mine',
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:3U21A07gAloCc4P7J8rxcn'],
#  ['Yikes', 'Kanye West', 'ye', True, 'spotify:track:1qsHYUd2c1wFGcn7e63QmG'],
#  ['Ghost Town',
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:7vgTNTaEz3CsBZ1N4YQalM'],
#  ["Wouldn't Leave",
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:1nGoy0cEj0extAwXYNYTWd'],
#  ['I Thought About Killing You',
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:0yhxBvedRdGxsPZHJNI4VA'],
#  ['Violent Crimes',
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:3s7MCdXyWmwjdcWh7GWXas'],
#  ['No Mistakes',
#   'Kanye West',
#   'ye',
#   True,
#   'spotify:track:35KV2Nuib6jPMVN00O8iba'],
#  ['Girls Like You (feat. Cardi B) - Cardi B Version',
#   'Maroon 5',
#   'Red Pill Blues (Deluxe)',
#   True,
#   'spotify:track:6V1bu6o1Yo5ZXnsCJU8Ovk'],
#  ['Back To You',
#   'Selena Gomez',
#   '13 Reasons Why (Season 2)',
#   False,
#   'spotify:track:514rhnksEwHUh6LxXsQ4Y9'],
#  ['Taste (feat. Offset)',
#   'Tyga',
#   'Legendary',
#   True,
#   'spotify:track:2toVe5hfuIi97ytDPDbQFt'],
#  ['TATI',
#   '6ix9ine',
#   'DUMMY BOY',
#   True,
#   'spotify:track:78MLMKaMyZvRUKUyVhyRi0'],
#  ['Youth (feat. Khalid)',
#   'Shawn Mendes',
#   'Shawn Mendes (Deluxe)',
#   False,
#   'spotify:track:5cWIKVqSpJQiRmG59sfii5'],
#  ['lovely (with Khalid)',
#   'Billie Eilish',
#   'lovely (with Khalid)',
#   False,
#   'spotify:track:0u2P5u6lvoDfwTYjAADbn4'],
#  ['Reborn',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:4RVbK6cV0VqWdpCDcx3hiT'],
#  ['4th Dimension',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:6JyEh4kl9DLwmSAoNDRn5b'],
#  ['Feel The Love',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:3aUFrxO1B8EW63QchEl3wX'],
#  ['Cudi Montage',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:4kUZvXB3LC3an3HX6h0s17'],
#  ['Fire',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:7oHkit3F3vimtsBbnZkU0G'],
#  ['Freeee (Ghost Town Pt. 2)',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:7GRTrWsP3yo2Fx8umJfA1X'],
#  ['Kids See Ghosts',
#   'KIDS SEE GHOSTS',
#   'KIDS SEE GHOSTS',
#   True,
#   'spotify:track:2I3dW2dCBZAJGj5X21E53k'],
#  ['APESHIT',
#   'The Carters',
#   'EVERYTHING IS LOVE',
#   True,
#   'spotify:track:0E6PsO3ymCfUh7pJQjBgkj'],
#  ['Bigger Than You (feat. Drake & Quavo)',
#   '2 Chainz',
#   'Bigger Than You feat. Drake & Quavo',
#   True,
#   'spotify:track:5S1IUPueD0xE0vj4zU3nSf'],
#  ['Bed (feat. Ariana Grande)',
#   'Nicki Minaj',
#   'Queen',
#   True,
#   'spotify:track:2Gyfmw1w1RpMyjBFe1784y'],
#  ['Youngblood',
#   '5 Seconds of Summer',
#   'Youngblood (Deluxe)',
#   False,
#   'spotify:track:2iUXsYOEPhVqEBwsqP70rE'],
#  ['BOSS',
#   'The Carters',
#   'EVERYTHING IS LOVE',
#   True,
#   'spotify:track:4F8V44j8cbjHnXjfW2HruU'],
#  ['SUMMER',
#   'The Carters',
#   'EVERYTHING IS LOVE',
#   False,
#   'spotify:track:54vcvhmByc2BC4k9JDcQrj'],
#  ['Cops Shot The Kid',
#   'Nas',
#   'NASIR',
#   True,
#   'spotify:track:1vi9adPJiD4d22ybGp25hy'],
#  ['NICE',
#   'The Carters',
#   'EVERYTHING IS LOVE',
#   True,
#   'spotify:track:44lusH2vzc4sRAwsooRhPh'],
#  ['FRIENDS',
#   'The Carters',
#   'EVERYTHING IS LOVE',
#   True,
#   'spotify:track:0gu5B9dUOiLezdDjrLPCCV'],
#  ['Tequila',
#   'Dan + Shay',
#   'Dan + Shay',
#   False,
#   'spotify:track:42fw0rxRO2xbesF6mJfd4Y'],
#  ['BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj)',
#   'YG',
#   'STAY DANGEROUS',
#   True,
#   'spotify:track:0ZNrc4kNeQYD9koZ3KvCsy'],
#  ['Nonstop',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:0TlLq3lA83rQOYtrqBqSct'],
#  ['Emotionless',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:5Psnhdkyanjpgc2P8A5TSM'],
#  ['In My Feelings',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:2G7V7zsVDxg1yRsu7Ew9RJ'],
#  ['Mob Ties',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:7rC5Pl8rQSX4myONQHYPBK'],
#  ['Elevate',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:3szf2z1Cy1QMrtHrbn8rz9'],
#  ['Don’t Matter To Me (with Michael Jackson)',
#   'Drake',
#   'Scorpion',
#   False,
#   'spotify:track:6G8kHiVZ1jW7vHMPVRNZU0'],
#  ['Survival',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:2yg9UN4eo5eMVJ7OB4RWj3'],
#  ['Can’t Take A Joke',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:1dUHF4RyMmMTveJ0Rby6Xm'],
#  ['8 Out Of 10',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:0zqy3ss4CwD6u4QPksS0nI'],
#  ['Sandra’s Rose',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:6cblRiEGDRNZgowcm951R3'],
#  ['Summer Games',
#   'Drake',
#   'Scorpion',
#   False,
#   'spotify:track:4HG1YiGBseVKzjyKcmAJen'],
#  ['Blue Tint',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:4n1bdaKwynQndm47x5HqWX'],
#  ['Jaded', 'Drake', 'Scorpion', True, 'spotify:track:4c2xt1trwYZpMqPWY35Xi9'],
#  ['Is There More',
#   'Drake',
#   'Scorpion',
#   True,
#   'spotify:track:1Tnw0ItH1Macok8gblnPPd'],
#  ['Peak', 'Drake', 'Scorpion', True, 'spotify:track:11L064movtyopGdLiX4sVg'],
# ...
#   'Dreamville',
#   'Revenge Of The Dreamers III',
#   True,
#   'spotify:track:5WnfnSpuNEGXyEt78PBA6d'],
#  ['LaLaLa',
#   'Jønny Ans',
#   'LaLaLa',
#   True,
#   'spotify:track:1nLBeJyfcCBjZcq4xi2rg8'],
#  ['The Git Up',
#   'Blanco Brown',
#   'Honeysuckle & Lightning Bugs',
#   False,
#   'spotify:track:2KKijf6Ett4kmVNJze2roh'],
#  ['Beautiful People (feat. Khalid)',
#   'Ed Sheeran',
#   'No.6 Collaborations Project',
#   False,
#   'spotify:track:70eFcWOvlMObDhURTqT4Fv'],
#  ['Baguettes in the Face (feat. NAV, Playboi Carti & A Boogie Wit da Hoodie)',
#   'Mustard',
#   'Perfect Ten',
#   True,
#   'spotify:track:2zjGJ0dChMR0KxBZS15aqo'],
#  ['LamboTruck (with Cozz feat. REASON & Childish Major)',
#   'Dreamville',
#   'Revenge Of The Dreamers III',
#   True,
#   'spotify:track:1OS9fNE87zO4Z696lBXriv'],
#  ['Antisocial (with Travis Scott)',
#   'Ed Sheeran',
#   'No.6 Collaborations Project',
#   False,
#   'spotify:track:1DhRbox3xkceP64k3JeYfW'],
#  ['South of the Border (feat. Camila Cabello & Cardi B)',
#   'Ed Sheeran',
#   'No.6 Collaborations Project',
#   False,
#   'spotify:track:4vUmTMuQqjdnvlZmAH61Qk'],
#  ['Remember The Name (feat. Eminem & 50 Cent)',
#   'Ed Sheeran',
#   'No.6 Collaborations Project',
#   True,
#   'spotify:track:0AtP8EkGPn6SwxKDaUuXec'],
#  ['Baby (Lil Baby feat. DaBaby)',
#   'Quality Control',
#   'Quality Control: Control The Streets Volume 2',
#   True,
#   'spotify:track:5MPPttjfGap2C6j6eKcO6J'],
#  ['How Do You Sleep?',
#   'Sam Smith',
#   'Love Goes',
#   False,
#   'spotify:track:34pRqzRiFcIuyRMuuEayzY'],
#  ['Cash Shit (feat. DaBaby)',
#   'Megan Thee Stallion',
#   'Fever',
#   True,
#   'spotify:track:2rMAtCaTj16NptyVfEIeAC'],
#  ['La La Land (feat. YG)',
#   'Bryce Vine',
#   'Carnival',
#   True,
#   'spotify:track:4oM9DGUTrRaXJDypxxHztZ'],
#  ['MOOD 4 EVA (feat. Oumou Sangaré)',
#   'Beyoncé',
#   'The Lion King: The Gift',
#   False,
#   'spotify:track:7oqftogUN82Q7VNy2TmTJW'],
#  ['BROWN SKIN GIRL',
#   'Blue Ivy',
#   'The Lion King: The Gift',
#   False,
#   'spotify:track:0B3FovCVaGKS5w1FTidEUP'],
#  ['My Type', 'Saweetie', 'ICY', True, 'spotify:track:5KBARWIxeMGkvUax9VtVC9'],
#  ['Gold Roses (feat. Drake)',
#   'Rick Ross',
#   'Port of Miami 2',
#   True,
#   'spotify:track:1rX5L6pyl3rVWb55D8Cprr'],
#  ['Hot Shower',
#   'Chance the Rapper',
#   'The Big Day',
#   True,
#   'spotify:track:00ko9WaS4jOX1kEk3gvHjf'],
#  ['Otro Trago',
#   'Sech',
#   'Sueños',
#   True,
#   'spotify:track:1Ej96GIBCTvgH7tNX1r3qr'],
#  ['Do You Remember',
#   'Chance the Rapper',
#   'The Big Day',
#   False,
#   'spotify:track:67xBtV07CC73eFw7z5oCvU'],
#  ['All Day Long',
#   'Chance the Rapper',
#   'The Big Day',
#   False,
#   'spotify:track:1g3ErLqysBJ5EIGdYYMWFZ'],
#  ['China',
#   'Anuel AA',
#   'Emmanuel',
#   False,
#   'spotify:track:0KkIkfsLEJbrcIhYsCL7L5'],
#  ['Single Again',
#   'Big Sean',
#   'Single Again',
#   True,
#   'spotify:track:7IP0lO9tHfNwBWZ9X6TJ84'],
#  ['The Archer',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:3pHkh7d0lzM2AldUtz2x37'],
#  ['boyfriend (with Social House)',
#   'Ariana Grande',
#   'boyfriend',
#   True,
#   'spotify:track:0Ryd8975WihbObpp5cPW1t'],
#  ['Trust Issues',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:4Wjhj0WjkyECccfHVIgaTq'],
#  ['The Motion',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:0Tacxc5lDJ8LwiO1pWNSl8'],
#  ['How Bout Now',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:4n4BflhWjCHIxrI4v7Xt9s'],
#  ['Dreams Money Can Buy',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:1qyFlfPREPbRcS2BNszdYI'],
#  ['Days in The East',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:4czcw3NVLY0of5hTD7OufN'],
#  ['Club Paradise',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:6MR5IBSNfDmiwnrlQpVw4w'],
#  ['4pm in Calabasas',
#   'Drake',
#   'Care Package',
#   True,
#   'spotify:track:6C9SwoZ5OrxcvkntgA5t8s'],
#  ['Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)',
#   'Megan Thee Stallion',
#   'Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)',
#   True,
#   'spotify:track:5N1o6d8zGcSZSeMFkOUQOk'],
#  ['Snake Skin',
#   'Trippie Redd',
#   '!',
#   True,
#   'spotify:track:1usK5eLBzpQTMwDt8SR2dr'],
#  ['Mac 10', 'Trippie Redd', '!', True, 'spotify:track:2KEux6D75xjj6fdabXpeAu'],
#  ["Ballin' (with Roddy Ricch)",
#   'Mustard',
#   'Perfect Ten',
#   True,
#   'spotify:track:3QzAOrNlsabgbMwlZt7TAY'],
#  ['Aston Martin Music',
#   'Rick Ross',
#   'Teflon Don',
#   True,
#   'spotify:track:5W7xC99N2Zzfh69r7I7zWK'],
#  ['Hot (feat. Gunna)',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:5Z8HZM6iQMhhqyPcCGY5g9'],
#  ['Bad Bad Bad (feat. Lil Baby)',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:1GeNui6m825V8jP4uKiIaH'],
#  ['Lover',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1dGr1c8CrMLDpV6mPbImSI'],
#  ["What's the Move (feat. Lil Uzi Vert)",
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:3pTScODwk9tggZzmuH6xDY'],
#  ['Just How It Is',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:5KYhIFNTp4VQUqlsbLWTTu'],
#  ['Surf (feat. Gunna)',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:6igOR5QCn09zAVF2ikZjsV'],
#  ['Slide Away',
#   'Miley Cyrus',
#   'Slide Away',
#   False,
#   'spotify:track:44ADyYoY5liaRa3EOAl4uf'],
#  ['Light It Up',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:41mzryVlFLlz6b1BCtJAjx'],
#  ['Motivation',
#   'Normani',
#   'Motivation',
#   False,
#   'spotify:track:0rIAC4PXANcKmitJfoqmVm'],
#  ['Lil Baby',
#   'Young Thug',
#   'So Much Fun',
#   True,
#   'spotify:track:1MGWgLxUXDodD8Tw8TFppN'],
#  ["Won't Be Late (feat. Drake)",
#   'Swae Lee',
#   "Won't Be Late (feat. Drake)",
#   False,
#   'spotify:track:2sqsNXfN0HtgDEgaHXiUTa'],
#  ["Knockin' Boots",
#   'Luke Bryan',
#   'Born Here Live Here Die Here',
#   False,
#   'spotify:track:2opQESZb7JsRKCvWMBPeuv'],
#  ['The Man',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:3RauEVgRgj1IuWdJ9fDs70'],
#  ['Cruel Summer',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'],
#  ['I Forgot That You Existed',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:43rA71bccXFGD4C8GOpIlN'],
#  ['Paper Rings',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:4y5bvROuBDPr5fuwXbIBZR'],
#  ['I Think He Knows',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:2YWtcWi3a83pdEg3Gif4Pd'],
#  ['Miss Americana & The Heartbreak Prince',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:214nt20w5wOxJnY462klLw'],
#  ['Cornelia Street',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:12M5uqx0ZuwkpLp5rJim1a'],
#  ['London Boy',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1LLXZFeAHK9R4xUramtUKw'],
#  ['Death By A Thousand Cuts',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:2dgFqt3w9xIQRjhPtwNk3D'],
#  ['Afterglow',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1SymEzIT3H8UZfibCs3TYi'],
#  ['False God',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:5hQSXkFgbxjZo9uCwd11so'],
#  ['Soon You’ll Get Better (feat. The Chicks)',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:4AYtqFyFbX0Xkc2wtcygTr'],
#  ['F.N',
#   'Lil Tjay',
#   'True 2 Myself',
#   True,
#   'spotify:track:0RLLvYBopDwooCyvnTwgYu'],
#  ['It’s Nice To Have A Friend',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1SmiQ65iSAbPto6gPFlBYm'],
#  ['Daylight',
#   'Taylor Swift',
#   'Lover',
#   False,
#   'spotify:track:1fzAuUVbzlhZ1lJAx9PtY6'],
#  ['Good as Hell',
#   'Lizzo',
#   'Cuz I Love You (Super Deluxe)',
#   False,
#   'spotify:track:6KgBpzTuTRPebChN0VTyzV'],
#  ['Circles',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   False,
#   'spotify:track:21jGcNKet2qwijlDFuPiPb'],
#  ['All To Myself',
#   'Dan + Shay',
#   'Dan + Shay',
#   False,
#   'spotify:track:08tq1XcHwVt5PHXUo87i0D'],
#  ["223's (feat. 9lokknine)",
#   'YNW Melly',
#   'Melly vs. Melvin',
#   True,
#   'spotify:track:29ZXwWOOLz9t5fa3eT3i7T'],
#  ['Did It Again',
#   'Lil Tecca',
#   'We Love You Tecca',
#   True,
#   'spotify:track:4guBZjUyrGoHsTahO3IHdj'],
#  ['Babushka Boi',
#   'A$AP Rocky',
#   'Babushka Boi',
#   True,
#   'spotify:track:643PW82aBMUa1FiWi5VQY7'],
#  ['Shots',
#   'Lil Tecca',
#   'We Love You Tecca',
#   True,
#   'spotify:track:6eSU1exzDvBEXmBRxspeh5'],
#  ['Love Me',
#   'Lil Tecca',
#   'We Love You Tecca',
#   True,
#   'spotify:track:4e0FYxSROat25pH16zMTZI'],
#  ['Enemies (feat. DaBaby)',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:0Xek5rqai2jcOWCYWJfVCF'],
#  ['Take What You Want (feat. Ozzy Osbourne & Travis Scott)',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   False,
#   'spotify:track:7CZyCXKG6d5ALeq41sLzbw'],
#  ["Hollywood's Bleeding",
#   'Post Malone',
#   "Hollywood's Bleeding",
#   False,
#   'spotify:track:7sWRlDoTDX8geTR8zzr2vt'],
#  ['Saint-Tropez',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:05mDaV9Vb3wrzjF6OPZnhq'],
#  ['Die For Me (feat. Future & Halsey)',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:2C6WXnmZ66tHhHlnvwePiK'],
#  ['On The Road (feat. Meek Mill & Lil Baby)',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:12Fkyg9lpmaz2zmKOfw2Y2'],
#  ['A Thousand Bad Times',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:2J0NXdHr6MYvKDSxB7k3V2'],
#  ["I'm Gonna Be",
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:1ckLp8lCl8LipXI0ypX72m'],
#  ['Staring At The Sun (feat. SZA)',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:5KE9b4x7Zj2A8XtbkqhqTe'],
#  ['Allergic',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:1YscJ7yVTlFxW3eF6pv5ba'],
#  ['I Know',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:6b2mfHMqWCA74XmUuVJm8r'],
#  ['Myself',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:2cvOfKHOHgwQlLiuLKP2xR'],
#  ['Internet',
#   'Post Malone',
#   "Hollywood's Bleeding",
#   True,
#   'spotify:track:0KAzP1Rbp0Vz5pw8i1KDDI'],
#  ['hot girl bummer',
#   'blackbear',
#   'everything means nothing',
#   True,
#   'spotify:track:6jRq8gaZhMUyy5RclRPcAf'],
#  ['INTRO', 'DaBaby', 'KIRK', True, 'spotify:track:77KMttn3Lic7ZQKDlPqp8v'],
#  ['Camelot',
#   'NLE Choppa',
#   'Top Shotta',
#   True,
#   'spotify:track:44sYqNBttbXNxya33FJ3Dj'],
#  ['Memories',
#   'Maroon 5',
#   'JORDI (Deluxe)',
#   False,
#   'spotify:track:4cktbXiXOapiLBMprHFErI'],
#  ['Behind Barz - Bonus',
#   'Drake',
#   'Top Boy (A Selection of Music Inspired by the Series)',
#   True,
#   'spotify:track:5r7WvQtyPfy1xch5zMgGRp'],
#  ['Don’t Call Me Angel (Charlie’s Angels) (with Miley Cyrus & Lana Del Rey)',
#   'Ariana Grande',
#   "Charlie's Angels (Original Motion Picture Soundtrack)",
#   False,
#   'spotify:track:6zegtH6XXd2PDPLvy1Y0n2'],
#  ['Playing Games (with Bryson Tiller) - Extended Version',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:2xyx0o4xNOLLjBSbOOdcbA'],
#  ['Satish',
#   'Tee Grizzley',
#   'Satish',
#   True,
#   'spotify:track:4hbcs8vaamKTPevPIJsY7N'],
#  ['BOP', 'DaBaby', 'KIRK', True, 'spotify:track:6Ozh9Ok6h4Oi1wUSLtBseN'],
#  ['VIBEZ', 'DaBaby', 'KIRK', True, 'spotify:track:0fySG6A6qLE8IvDpayb5bM'],
#  ['TOES (feat. Lil Baby & Moneybagg Yo)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:2FvD20Z8aoWIePi7PoN8sG'],
#  ['OFF THE RIP',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:3e39X4Q74yJzsYUEeyf4ws'],
#  ['iPHONE (with Nicki Minaj)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:3GX2hFAekmSduZzcS52OnR'],
#  ['POP STAR (feat. Kevin Gates)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:2TsD9kSbgYx5fSNRsoNURE'],
#  ['RAW SHIT (feat. Migos)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:1CCDIow4pPYyJYzhtTUYz2'],
#  ['GOSPEL (feat. Chance The Rapper, Gucci Mane & YK Osiris)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:0WoAkdHmgPmEXfiBox1flk'],
#  ['REALLY (feat. Stunna 4 Vegas)',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:7vxGCUPJhe0fXfBkwVPFcP'],
#  ['XXL', 'DaBaby', 'KIRK', True, 'spotify:track:4LH1gsNA3wUS6QKkGZoJN8'],
#  ['PROLLY HEARD',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:0O7mJ0noFBLn8MMUJrFaF1'],
#  ['THERE HE GO',
#   'DaBaby',
#   'KIRK',
#   True,
#   'spotify:track:0pegcONe6MuDQRoPCtCBRf'],
#  ['HIGHEST IN THE ROOM',
#   'Travis Scott',
#   'HIGHEST IN THE ROOM',
#   True,
#   'spotify:track:3eekarcy7kvN4yt5ZFzltW'],
#  ['Bandit (with YoungBoy Never Broke Again)',
#   'Juice WRLD',
#   'Death Race For Love (Bonus Track Version)',
#   True,
#   'spotify:track:1oWM79mUVdZGCGYjSirHZR'],
#  ['10,000 Hours (with Justin Bieber)',
#   'Dan + Shay',
#   '10,000 Hours (with Justin Bieber)',
#   False,
#   'spotify:track:2wrJq5XKLnmhRXHIAf9xBa'],
#  ['Come Thru (with Usher)',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:3TTMUI5dFcbeNSDTTDY9M8'],
#  ['Stretch You Out (feat. A Boogie wit da Hoodie)',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:4Qxn47gWPSucovKrMyRf1z'],
#  ['Body',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:7vxLj7MREliG5i5vSnqSVr'],
#  ['Drunk Dialing...LODT',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:0pzWCDSuVRX7m95EFOxVa0'],
#  ['Over It',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:0csmcZqM3uTKfjxehw0Lw2'],
#  ["I'll Kill You (feat. Jhené Aiko)",
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:7EkiMl81fUHVwpItgtzI4r'],
#  ['Potential',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:4YNrBVo8fv6qiTNwHLVDai'],
#  ['Just Might (with PARTYNEXTDOOR)',
#   'Summer Walker',
#   'Over It',
#   True,
#   'spotify:track:43IMaycr34ZR5kS8mlL5hH'],
#  ['Lights Up',
#   'Harry Styles',
#   'Fine Line',
#   False,
#   'spotify:track:4jAIqgrPjKLTY9Gbez25Qb'],
#  ['Make No Sense',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:6klLvorLoo1sxvZcjJIY8I'],
#  ['Lonely Child',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:6xqZi5JTTk6XIMLvy7w5JJ'],
#  ['Self Control',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:4vSoyDfL0uZyUoWu5NNNsQ'],
#  ['Carter Son',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:0QVvkAOstRG26pVYN95CeL'],
#  ['Hot Now',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:3eeyKNIBrt5TH4y0y3QkOu'],
#  ["Time I'm On",
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:6vWzkhoAp1SF4PEJ0iLKYQ'],
#  ['Rich As Hell',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:5A6tFAdihqILHJrWuR6wD4'],
#  ['Ranada',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:4XlyD28tQ6qdqNS2BkE1AF'],
#  ['In Control',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:5IdAcHb4cwtexqMlOojWhR'],
#  ["Rebel's Kick It",
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:3hYBu3LRhapDItoL2R5aK2'],
#  ['Seeming Like It',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:0eGvris9sYZMOsTMHT20Td'],
#  ['Gang Shit',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:0igHhcoLY0yHVPHiPvGuXx'],
#  ['Slime Mentality',
#   'YoungBoy Never Broke Again',
#   'AI YoungBoy 2',
#   True,
#   'spotify:track:2m9axSosHP92250FvnnobM'],
#  ['Lose You To Love Me',
#   'Selena Gomez',
#   'Rare',
#   False,
#   'spotify:track:4l0Mvzj72xxOpRrp6h8nHi'],
#  ['Dance Monkey',
#   'Tones And I',
#   'The Kids Are Coming',
#   False,
#   'spotify:track:5ZULALImTm80tzUbYQYM9d'],
#  ['Trampoline',
#   'SHAED',
#   'MELT',
#   False,
#   'spotify:track:0lsRatBUs9HNIZAmoGABzk'],
#  ['Stuck In A Dream (feat. Gunna)',
#   'Lil Mosey',
#   'Certified Hitmaker (AVA Leak)',
#   True,
#   'spotify:track:0oUITXYdiwBki5HHaHNeNn'],
#  ['DHL', 'Frank Ocean', 'DHL', True, 'spotify:track:2INhKpUdzh7v0j041gZNsz'],
#  ['Heartless (feat. Morgan Wallen)',
#   'Diplo',
#   'Diplo Presents Thomas Wesley Chapter 1: Snake Oil',
#   True,
#   'spotify:track:3FU6urUVsgXa6RBuV2PdRk'],
#  ['Follow God',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:2QpGZOhTCHHiKmpSO9FW4h'],
#  ['Closed On Sunday',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:3JWiDGQX2eTlFvKj3Yssj3'],
#  ['On God',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:2SasoXZyv82yYgHiVOvxQn'],
#  ['Selah',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:39JRmdKFka1Oe09FoOCPI4'],
#  ['Everything We Need',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:24bnCCysWnbNRNUT4LpHcP'],
#  ['Use This Gospel',
#   'Kanye West',
#   'JESUS IS KING',
#   False,
#   'spotify:track:0oPOuDmmkVp3h6puekhs6P'],
#  ...]

# %%
#convert list to DataFrame
uri_df = pd.DataFrame(song_list,columns=["song","artist","album","explicit","uri"])

#change index to start at 1
uri_df.index = range(1,len(uri_df)+1)
uri_df
# Out:
#                                song             artist  \
# 1                           The One   The Chainsmokers
# 2                        Sacrifices              Drake
# 3                            Closer   The Chainsmokers
# 4                           Starboy         The Weeknd
# 5                   Get It Together              Drake
# ...                             ...                ...
# 1985                   Freaky Deaky               Tyga
# 1986                  Banking On Me              Gunna
# 1987                Numb Little Bug         Em Beihold
# 1988  Rocking A Cardigan in Atlanta  lil Shordie Scott
# 1989     Bam Bam (feat. Ed Sheeran)     Camila Cabello
#
#                               album explicit  \
# 1            Memories...Do Not Open     True
# 2                         More Life     True
# 3                            Closer    False
# 4                           Starboy     True
# 5                         More Life     True
# ...                             ...      ...
# 1985                   Freaky Deaky     True
# 1986                  Banking On Me     True
# 1987                Numb Little Bug    False
# 1988  Rocking A Cardigan in Atlanta     True
# 1989     Bam Bam (feat. Ed Sheeran)    False
#
#                                        uri
# 1     spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 2     spotify:track:0xl1w2q4VLojeXp4JfazPL
# 3     spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 4     spotify:track:7MXVkk9YMctZqd1Srtv4MB
# 5     spotify:track:7y6c07pgjZvtHI9kuMVqk1
# ...                                    ...
# 1985  spotify:track:3vySEUpD0tc801F2WZDLYw
# 1986  spotify:track:7Fege3yv4dvehB3NdRBGwI
# 1987  spotify:track:3o9kpgkIcffx0iSwxhuNI2
# 1988  spotify:track:0N0h5lXc4HOiLgGb9EZi8m
# 1989  spotify:track:0QBzMgT7NIeoCYy3sJCof1
#
# [1989 rows x 5 columns]

# %%
#check for any songs that don't have URIs
data_to_clean = uri_df[uri_df['uri'] == ""]
data_to_clean.index = range(1,len(data_to_clean)+1)
data_to_clean

data_to_clean[:]
# Out:
#                                                 song         artist  \
# 1  SORRY NOT SORRY (feat. Nas, JAY-Z & James Faun...      DJ Khaled
# 2          NOT SOBER (feat. Polo G & Stunna Gambino)  The Kid LAROI
#
#                     album explicit uri
# 1           KHALED KHALED
# 2  F*CK LOVE 3+: OVER YOU

# %% [markdown]
# The search-for-URI function worked with a 99.8+% success rate!
#
# For the songs that didn't get a URI, individually check what searching it on Spotify's API would result in using the following function.
#
# From there, get the URI for the desired song/version of a song, manually enter it into uri_df, and update and check the data_to_clean dataframe created above until there is nothing left in data_to_clean.

# %%
"""
If a song doesn't have URI, individually check what searching it in Spotify's API would result in

Use your browser to look up a URI to double-check you get your desired version of a song
"""

#change q to adjust for your desired song search
result = sp.search(q="NOT SOBER     The Kid LAROI ")
for song_info_dict in range(len(result['tracks']['items'])):
    print(result['tracks']['items'][song_info_dict]['name'])
    print(result['tracks']['items'][song_info_dict]['artists'][0]['name'])
    print(result['tracks']['items'][song_info_dict]['album']['name'])
    print(result['tracks']['items'][song_info_dict]['explicit'])
    print(result['tracks']['items'][song_info_dict]['uri'],"\n")
# Out:
# NOT SOBER (feat. Polo G & Stunna Gambino)
# The Kid LAROI
# F*CK LOVE 3: OVER YOU
# True
# spotify:track:1JXBNvlDEl2epKSJ9EOgKX
#
# STAY (with Justin Bieber)
# The Kid LAROI
# STAY (with Justin Bieber)
# True
# spotify:track:5HCyWlXZPP0y6Gqq8TgA20
#
# NOT SOBER (feat. Polo G & Stunna Gambino)
# The Kid LAROI
# F*CK LOVE 3+: OVER YOU
# True
# spotify:track:29t9XYOV65fFXiVzFFJgHH
#
# Hate The Other Side (with Marshmello & The Kid Laroi)
# Juice WRLD
# Legends Never Die
# True
# spotify:track:0ada5XsQGLPUVbmTCkAP49
#
# NOT SOBER (feat. Polo G & Stunna Gambino)
# The Kid LAROI
# F*CK LOVE 3+: OVER YOU
# False
# spotify:track:2bFqWhULDfCMc2tlr39hOX
#
# STAY (with Justin Bieber)
# The Kid LAROI
# F*CK LOVE 3: OVER YOU
# True
# spotify:track:5PjdY0CKGZdEuoNab3yDmX
#
# WITHOUT YOU
# The Kid LAROI
# F*CK LOVE (SAVAGE)
# True
# spotify:track:27OeeYzk6klgBh83TSvGMA
#
# GO (feat. Juice WRLD)
# The Kid LAROI
# F*CK LOVE
# True
# spotify:track:2rPHUAeUPbNgTmK18FPTiZ
#
# Costa Rica (feat. The Kid LAROI) - Remix
# Bankrol Hayden
# Pain is Temporary
# True
# spotify:track:3tdjTdCCgKtwacsICCtPZZ
#
# No Return (with The Kid LAROI & Lil Durk)
# Polo G
# Hall of Fame
# True
# spotify:track:23OYT3SFtoJqhiAUqktbc1

# %%
"""
manually adding the URIs
"""

#fixing data from Not Sober by The Kid LAROI 
uri_df.loc[1710]['explicit'] = True
uri_df.loc[1710]['uri'] = "spotify:track:29t9XYOV65fFXiVzFFJgHH"

#update and check data_to_clean using the code below this cell

#fixing data from Sorry Not Sorry by DJ Khaled
uri_df.loc[1599]['explicit'] = True
uri_df.loc[1599]['uri'] = "spotify:track:5OypcrFg58e4k2iYHi69ED"
#update and check data_to_clean using the code below this cell

# %%
#run to update and check data_to_clean
data_to_clean = uri_df[uri_df['uri'] == ""]
data_to_clean.index = range(1,len(data_to_clean)+1)
data_to_clean
data_to_clean[:]

#repeat this and update uri's manually until data_to_clean is empty
# Out:
# Empty DataFrame
# Columns: [song, artist, album, explicit, uri]
# Index: []

# %%
#check final uri_df with all URIs
uri_df
# Out:
#                                song             artist  \
# 1                           The One   The Chainsmokers
# 2                        Sacrifices              Drake
# 3                            Closer   The Chainsmokers
# 4                           Starboy         The Weeknd
# 5                   Get It Together              Drake
# ...                             ...                ...
# 1985                   Freaky Deaky               Tyga
# 1986                  Banking On Me              Gunna
# 1987                Numb Little Bug         Em Beihold
# 1988  Rocking A Cardigan in Atlanta  lil Shordie Scott
# 1989     Bam Bam (feat. Ed Sheeran)     Camila Cabello
#
#                               album explicit  \
# 1            Memories...Do Not Open     True
# 2                         More Life     True
# 3                            Closer    False
# 4                           Starboy     True
# 5                         More Life     True
# ...                             ...      ...
# 1985                   Freaky Deaky     True
# 1986                  Banking On Me     True
# 1987                Numb Little Bug    False
# 1988  Rocking A Cardigan in Atlanta     True
# 1989     Bam Bam (feat. Ed Sheeran)    False
#
#                                        uri
# 1     spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 2     spotify:track:0xl1w2q4VLojeXp4JfazPL
# 3     spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 4     spotify:track:7MXVkk9YMctZqd1Srtv4MB
# 5     spotify:track:7y6c07pgjZvtHI9kuMVqk1
# ...                                    ...
# 1985  spotify:track:3vySEUpD0tc801F2WZDLYw
# 1986  spotify:track:7Fege3yv4dvehB3NdRBGwI
# 1987  spotify:track:3o9kpgkIcffx0iSwxhuNI2
# 1988  spotify:track:0N0h5lXc4HOiLgGb9EZi8m
# 1989  spotify:track:0QBzMgT7NIeoCYy3sJCof1
#
# [1989 rows x 5 columns]

# %% [markdown]
# ## Get spotipy's API information

# %% [markdown]
# Spotify has a plethora of information on a song's characteristics. The following functions/cells create a dataframe with song characteristic information on each song from the Google Sheet.

# %%
"""
takes in a song's URI
returns information on a song's characteristics
"""
def getTrackFeatures(track_id):
    md = sp.track(track_id)
    features = sp.audio_features(track_id)
    
    #meta data
    name = md['name']
    album = md['album']['name']
    artist = md['album']['artists'][0]['name']
    release_date = md['album']['release_date']
    length = md['duration_ms']
    popularity = md['popularity']
    
    #features from the data
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    key = features[0]['key']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    mode = features[0]['mode']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']
    valence = features[0]['valence']
    
    #putting it all together
    track = [name, album, artist, release_date, length, popularity, 
             acousticness, danceability, energy, instrumentalness, key,
            liveness, loudness, mode, speechiness, 
             tempo, time_signature, valence]
    
    return track

# %% [markdown]
# Similar to a previous function, the following function takes a while to execute, as it looks up track features for ~2000 songs from Spotify's API. To measure performance, a timer is used.

# %%
#Get track features for all tracks, append to a list

#start timer
start = time.process_time() 

tracks = []

[tracks.append( getTrackFeatures(uri_df['uri'][i]) ) for i in range(1,len(uri_df['uri'])+1)]

#print time
print(time.process_time() - start)
# Out:
# 55.85031500000002

# %%
#Convert list to DataFrame

api_info_df = pd.DataFrame(tracks,columns=['name','album','artist',
    'release_date','length','popularity','acousticness','danceability',
    'energy','instrumentalness','key','liveness','loudness','mode',
    'speechiness','tempo','time_signature','valence'])

#change index to start at one
api_info_df.index = range(1,len(api_info_df)+1)

#change release_date to date format
api_info_df['release_date'] = pd.to_datetime(api_info_df['release_date'])

api_info_df
# Out:
#                                name                          album  \
# 1                           The One         Memories...Do Not Open
# 2                        Sacrifices                      More Life
# 3                            Closer                         Closer
# 4                           Starboy                        Starboy
# 5                   Get It Together                      More Life
# ...                             ...                            ...
# 1985                   Freaky Deaky                   Freaky Deaky
# 1986                  Banking On Me                  Banking On Me
# 1987                Numb Little Bug                Numb Little Bug
# 1988  Rocking A Cardigan in Atlanta  Rocking A Cardigan in Atlanta
# 1989     Bam Bam (feat. Ed Sheeran)     Bam Bam (feat. Ed Sheeran)
#
#                  artist release_date  length  popularity  acousticness  \
# 1      The Chainsmokers   2017-04-07  177573          64        0.2380
# 2                 Drake   2017-03-18  307593          64        0.0407
# 3      The Chainsmokers   2016-07-29  244960          88        0.4140
# 4            The Weeknd   2016-11-25  230453          88        0.1410
# 5                 Drake   2017-03-18  250337          73        0.0945
# ...                 ...          ...     ...         ...           ...
# 1985               Tyga   2022-02-25  215281          86        0.0190
# 1986              Gunna   2022-02-14  200000          84        0.6130
# 1987         Em Beihold   2022-01-28  169237          90        0.3270
# 1988  lil Shordie Scott   2022-01-29   96825          83        0.5830
# 1989     Camila Cabello   2022-03-04  206070          89        0.1820
#
#       danceability  energy  instrumentalness  key  liveness  loudness  mode  \
# 1            0.760   0.303          0.000008    2    0.2940   -11.362     1
# 2            0.903   0.439          0.000000    8    0.1380   -11.813     1
# 3            0.748   0.524          0.000000    8    0.1110    -5.599     1
# 4            0.679   0.587          0.000006    7    0.1370    -7.015     1
# 5            0.781   0.721          0.391000    5    0.1040    -9.133     0
# ...            ...     ...               ...  ...       ...       ...   ...
# 1985         0.799   0.653          0.000000    2    0.0935    -5.453     0
# 1986         0.793   0.308          0.000017    0    0.0953   -10.414     0
# 1987         0.742   0.527          0.000000    8    0.2500    -6.892     0
# 1988         0.803   0.640          0.000331    1    0.4370    -4.721     1
# 1989         0.756   0.697          0.000000    8    0.3330    -6.377     1
#
#       speechiness    tempo  time_signature  valence
# 1          0.0284   99.991               4    0.150
# 2          0.3970  139.112               4    0.532
# 3          0.0338   95.010               4    0.661
# 4          0.2760  186.003               4    0.486
# 5          0.0514  123.011               4    0.849
# ...           ...      ...             ...      ...
# 1985       0.0370  104.019               4    0.236
# 1986       0.0466  135.143               4    0.460
# 1987       0.0769   84.974               4    0.638
# 1988       0.1510  140.073               4    0.816
# 1989       0.0401   94.996               4    0.956
#
# [1989 rows x 18 columns]

# %% [markdown]
# ## Joining all the data

# %% [markdown]
# Combine all the data collected/generated above!

# %%
#concatinate all variables into a final dataframe
final_df = pd.concat([gsheets_df.loc[:,'title':'album'],
                        uri_df.loc[:,'uri'] ,
                        gsheets_df.loc[:,'peak_date':'peak_week_streams'],
                      api_info_df.loc[:,'release_date':'valence'],
                      uri_df.loc[:,'explicit'],
                      gsheets_df.loc[:,'2022-02-25':'2017-03-31']
                      ],
                  axis=1)
final_df
# Out:
#                               title             artist  \
# 1                           The One   The Chainsmokers
# 2                        Sacrifices              Drake
# 3                            Closer   The Chainsmokers
# 4                           Starboy         The Weeknd
# 5                   Get It Together              Drake
# ...                             ...                ...
# 1985                   Freaky Deaky               Tyga
# 1986                  Banking On Me              Gunna
# 1987                Numb Little Bug         Em Beihold
# 1988  Rocking A Cardigan in Atlanta  lil Shordie Scott
# 1989     Bam Bam (feat. Ed Sheeran)     Camila Cabello
#
#                               album                                   uri  \
# 1            Memories...Do Not Open  spotify:track:0wfbD5rAksdXUzRvMfM3x5
# 2                         More Life  spotify:track:0xl1w2q4VLojeXp4JfazPL
# 3                            Closer  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 4                           Starboy  spotify:track:7MXVkk9YMctZqd1Srtv4MB
# 5                         More Life  spotify:track:7y6c07pgjZvtHI9kuMVqk1
# ...                             ...                                   ...
# 1985                   Freaky Deaky  spotify:track:3vySEUpD0tc801F2WZDLYw
# 1986                  Banking On Me  spotify:track:7Fege3yv4dvehB3NdRBGwI
# 1987                Numb Little Bug  spotify:track:3o9kpgkIcffx0iSwxhuNI2
# 1988  Rocking A Cardigan in Atlanta  spotify:track:0N0h5lXc4HOiLgGb9EZi8m
# 1989     Bam Bam (feat. Ed Sheeran)  spotify:track:0QBzMgT7NIeoCYy3sJCof1
#
#       peak_date  streams_2017_to_present  total_streams_2020s  \
# 1    2017-01-08                  7309244                    0
# 2    2017-03-18                 14042132                    0
# 3    2017-01-08                 10948414                    0
# 4    2017-01-08                 10554623                    0
# 5    2017-03-18                 11672736                    0
# ...         ...                      ...                  ...
# 1985 2022-02-25                  6374767              6374767
# 1986 2022-02-18                 19690109             19690109
# 1987 2022-03-04                 12762392             12762392
# 1988 2022-03-04                  6792715              6792715
# 1989 2022-03-04                  5942657              5942657
#
#       peak_week_streams release_date  length  ...  2017-06-02  2017-05-26  \
# 1               7309244   2017-04-07  177573  ...           0           0
# 2               7745212   2017-03-18  307593  ...           0           0
# 3               5528407   2016-07-29  244960  ...           0           0
# 4               5329562   2016-11-25  230453  ...           0           0
# 5               6461693   2017-03-18  250337  ...           0           0
# ...                 ...          ...     ...  ...         ...         ...
# 1985            6374767   2022-02-25  215281  ...           0           0
# 1986            7305777   2022-02-14  200000  ...           0           0
# 1987            7061002   2022-01-28  169237  ...           0           0
# 1988            6792715   2022-01-29   96825  ...           0           0
# 1989            5942657   2022-03-04  206070  ...           0           0
#
#       2017-05-19  2017-05-12  2017-05-05  2017-04-28  2017-04-21  2017-04-14  \
# 1              0           0           0           0           0           0
# 2              0           0           0           0           0           0
# 3              0           0           0           0           0           0
# 4              0           0           0           0           0           0
# 5              0           0           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 1985           0           0           0           0           0           0
# 1986           0           0           0           0           0           0
# 1987           0           0           0           0           0           0
# 1988           0           0           0           0           0           0
# 1989           0           0           0           0           0           0
#
#       2017-04-07  2017-03-31
# 1        7309244           0
# 2        6296920     7745212
# 3        5528407     5420007
# 4        5225061     5329562
# 5        5211043     6461693
# ...          ...         ...
# 1985           0           0
# 1986           0           0
# 1987           0           0
# 1988           0           0
# 1989           0           0
#
# [1989 rows x 280 columns]

# %%
#convert length (milliseconds) to min:sec:millisecond format
def ms_to_time(ms):
    millis = ms
    seconds=(millis/1000)%60
    seconds = int(seconds)
    minutes=(millis/(1000*60))%60
    minutes = int(minutes)
    
    #a string will be returned so add 0 before songs with length < 10 mins so that songs above 10 mins won't be misordered when ordering by min:sec:ms format
    if minutes < 10:
        return "0%d:%d:%d" % (minutes, seconds, millis)
    else:
        return "%d:%d:%d" % (minutes, seconds, millis)
    
#apply the function to final_df['length']
final_df['min_sec_mls'] = final_df['length'].apply(lambda x: ms_to_time(x))
# Out:
# 09:48:588139

# %% [markdown]
# ## Data Analysis (Song Length)

# %%
final_df.sort_values('length')
# Out:
#                                                   title              artist  \
# 1326              Juice WRLD Speaks From Heaven - Outro          Juice WRLD
# 505                          raindrops (an angel cried)       Ariana Grande
# 1302                       Bad Bitch From Tokyo (Intro)           Pop Smoke
# 1006                                      Jesus Is Lord          Kanye West
# 1763                                        Donda Chant          Kanye West
# ...                                                 ...                 ...
# 15                                                FEAR.      Kendrick Lamar
# 1684                                           WILSHIRE  Tyler, The Creator
# 1759                                         Jesus Lord          Kanye West
# 1688  SWEET / I THOUGHT YOU WANTED TO DANCE (feat. B...  Tyler, The Creator
# 1862  All Too Well (10 Minute Version) (Taylor's Ver...        Taylor Swift
#
#                                      album  \
# 1326                     Legends Never Die
# 505                              Sweetener
# 1302  Shoot For The Stars Aim For The Moon
# 1006                         JESUS IS KING
# 1763                                 Donda
# ...                                    ...
# 15                                   DAMN.
# 1684               CALL ME IF YOU GET LOST
# 1759                                 Donda
# 1688               CALL ME IF YOU GET LOST
# 1862                Red (Taylor's Version)
#
#                                        uri   peak_date  \
# 1326  spotify:track:1OjiYjgPZyxS0AiXiSnuYI  2020-07-10
# 505   spotify:track:0v2LUO8oTHnkjQ8MmKuXyk  2018-08-17
# 1302  spotify:track:4OGIeHtYhRTJ8iW21UUyZW  2020-07-03
# 1006  spotify:track:7sBgFMWqDWQgrsNSpIBoe8  2019-10-25
# 1763  spotify:track:7eSSmgq26BXr7xay3WKjfi  2021-08-27
# ...                                    ...         ...
# 15    spotify:track:23luOrEVHMfoX0AhfbQuS6  2017-04-14
# 1684  spotify:track:1pbbsI2KGPOMu0HmuGccBu  2021-06-25
# 1759  spotify:track:1LwdWIbfuqlOo8vlHxkyna  2021-08-27
# 1688  spotify:track:3EG9FJ0ToLfgnc1IG2Z1wz  2021-06-25
# 1862  spotify:track:5enxwA8aAbwZbf5qCHORXi  2021-11-12
#
#       streams_2017_to_present  total_streams_2020s  peak_week_streams  \
# 1326                  9414576              9414576            9414576
# 505                   6761327                    0            6761327
# 1302                 10488880             10488880           10488880
# 1006                 11326298                    0           11326298
# 1763                  7803482              7803482            7803482
# ...                       ...                  ...                ...
# 15                   16811902                    0           16811902
# 1684                  9945175              9945175            9945175
# 1759                 18908607             18908607           10204183
# 1688                  8465252              8465252            8465252
# 1862                115009493            115009493           39039454
#
#      release_date  length  ...  2017-05-26  2017-05-19  2017-05-12  \
# 1326   2020-07-10   30582  ...           0           0           0
# 505    2018-08-17   37640  ...           0           0           0
# 1302   2020-07-03   48000  ...           0           0           0
# 1006   2019-10-25   49292  ...           0           0           0
# 1763   2021-08-29   52061  ...           0           0           0
# ...           ...     ...  ...         ...         ...         ...
# 15     2017-04-14  460573  ...           0           0           0
# 1684   2021-06-25  515865  ...           0           0           0
# 1759   2021-08-29  538536  ...           0           0           0
# 1688   2021-06-25  588139  ...           0           0           0
# 1862   2021-11-12  613026  ...           0           0           0
#
#       2017-05-05  2017-04-28  2017-04-21  2017-04-14  2017-04-07  2017-03-31  \
# 1326           0           0           0           0           0           0
# 505            0           0           0           0           0           0
# 1302           0           0           0           0           0           0
# 1006           0           0           0           0           0           0
# 1763           0           0           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 15             0           0           0    16811902           0           0
# 1684           0           0           0           0           0           0
# 1759           0           0           0           0           0           0
# 1688           0           0           0           0           0           0
# 1862           0           0           0           0           0           0
#
#        min_sec_mls
# 1326   00:30:30582
# 505    00:37:37640
# 1302   00:48:48000
# 1006   00:49:49292
# 1763   00:52:52061
# ...            ...
# 15    07:40:460573
# 1684  08:35:515865
# 1759  08:58:538536
# 1688  09:48:588139
# 1862  10:13:613026
#
# [1989 rows x 281 columns]

# %%
sns.distplot(final_df['length'])

print("mean time for songs in the data set is:", ms_to_time(final_df['length'].mean()))
print("median time for songs in the data set is:", ms_to_time(final_df['length'].median()))
print(len(final_df), "songs appeared on the HITS Streaming Chart since 2017")
# Out:
# mean time for songs in the data set is: 03:21:201035
# median time for songs in the data set is: 03:17:197417
# 1989 songs appeared on the HITS Streaming Chart since 2017

# %% [markdown]
# Most songs seem to hover around the 3 minutes 20 seconds mark.
#
# This is remarkable because many articles in recent years reported hit songs decreasing in length in these last several years because of streaming.
#
# As a result the following dataframes isolates for songs that earned at a minimum threshold of streams while they were in the top 50 of the HITS streaming chart.

# %%
songs_over_50_mil = final_df[final_df['streams_2017_to_present'] > 50000000]
songs_over_50_mil.index = range(1,len(songs_over_50_mil)+1)
songs_over_50_mil

sns.distplot(songs_over_50_mil['length'])

print("mean time for songs with at least 50 mil streams during their time in the top 50 is:", ms_to_time(songs_over_50_mil['length'].mean()))
print("median time for songs with at least 50 mil streams during their time in the top 50 is:", ms_to_time(songs_over_50_mil['length'].median()))
print(len(songs_over_50_mil), "songs earned over 50 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 50 mil streams during their time in the top 50 is: 03:21:201318
# median time for songs with at least 50 mil streams during their time in the top 50 is: 03:19:199240
# 582 songs earned over 50 mil streams during their time in the top 50 since 2017

# %%
songs_over_100_mil = final_df[final_df['streams_2017_to_present'] > 100000000]
songs_over_100_mil.index = range(1,len(songs_over_100_mil)+1)
songs_over_100_mil

sns.distplot(songs_over_100_mil['length'])

print("mean time for songs with at least 100 mil streams during their time in the top 50 is:", ms_to_time(songs_over_100_mil['length'].mean()))
print("median time for songs with at least 100 mil streams during their time in the top 50 is:", ms_to_time(songs_over_100_mil['length'].median()))
print(len(songs_over_100_mil), "songs earned over 100 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 100 mil streams during their time in the top 50 is: 03:20:200690
# median time for songs with at least 100 mil streams during their time in the top 50 is: 03:20:200203
# 358 songs earned over 100 mil streams during their time in the top 50 since 2017

# %%
songs_over_200_mil = final_df[final_df['streams_2017_to_present'] > 200000000]
songs_over_200_mil.index = range(1,len(songs_over_200_mil)+1)
songs_over_200_mil

sns.distplot(songs_over_200_mil['length'])

print("mean time for songs with at least 200 mil streams during their time in the top 50 is:", ms_to_time(songs_over_200_mil['length'].mean()))
print("median time for songs with at least 200 mil streams during their time in the top 50 is:", ms_to_time(songs_over_200_mil['length'].median()))
print(len(songs_over_200_mil), "songs earned over 200 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 200 mil streams during their time in the top 50 is: 03:17:197203
# median time for songs with at least 200 mil streams during their time in the top 50 is: 03:15:195428
# 187 songs earned over 200 mil streams during their time in the top 50 since 2017

# %%
songs_over_300_mil = final_df[final_df['streams_2017_to_present'] > 300000000]
songs_over_300_mil.index = range(1,len(songs_over_300_mil)+1)
songs_over_300_mil

sns.distplot(songs_over_300_mil['length'])

print("mean time for songs with at least 300 mil streams during their time in the top 50 is:", ms_to_time(songs_over_300_mil['length'].mean()))
print("median time for songs with at least 300 mil streams during their time in the top 50 is:", ms_to_time(songs_over_300_mil['length'].median()))
print(len(songs_over_300_mil), "songs earned over 300 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 300 mil streams during their time in the top 50 is: 03:20:200241
# median time for songs with at least 300 mil streams during their time in the top 50 is: 03:21:201552
# 106 songs earned over 200 mil streams during their time in the top 50 since 2017

# %%
songs_over_400_mil = final_df[final_df['streams_2017_to_present'] > 400000000]
songs_over_400_mil.index = range(1,len(songs_over_400_mil)+1)
songs_over_400_mil

sns.distplot(songs_over_400_mil['length'])

print("mean time for songs with at least 400 mil streams during their time in the top 50 is:", ms_to_time(songs_over_400_mil['length'].mean()))
print("median time for songs with at least 400 mil streams during their time in the top 50 is:", ms_to_time(songs_over_400_mil['length'].median()))
print(len(songs_over_400_mil), "songs earned over 400 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 400 mil streams during their time in the top 50 is: 03:16:196224
# median time for songs with at least 400 mil streams during their time in the top 50 is: 03:16:196040
# 56 songs earned over 400 mil streams during their time in the top 50 since 2017

# %%
songs_over_500_mil = final_df[final_df['streams_2017_to_present'] > 500000000]
songs_over_500_mil.index = range(1,len(songs_over_500_mil)+1)
songs_over_500_mil

sns.distplot(songs_over_500_mil['length'])

print("mean time for songs with at least 500 mil streams during their time in the top 50 is:", ms_to_time(songs_over_500_mil['length'].mean()))
print("median time for songs with at least 500 mil streams during their time in the top 50 is:", ms_to_time(songs_over_500_mil['length'].median()))
print(len(songs_over_500_mil), "songs earned over 500 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 500 mil streams during their time in the top 50 is: 03:19:199522
# median time for songs with at least 500 mil streams during their time in the top 50 is: 03:19:199506
# 36 songs earned over 500 mil streams during their time in the top 50 since 2017

# %%
songs_over_600_mil = final_df[final_df['streams_2017_to_present'] > 600000000]
songs_over_600_mil.index = range(1,len(songs_over_600_mil)+1)
songs_over_600_mil

sns.distplot(songs_over_600_mil['length'])

print("mean time for songs with at least 600 mil streams during their time in the top 50 is:", ms_to_time(songs_over_600_mil['length'].mean()))
print("median time for songs with at least 600 mil streams during their time in the top 50 is:", ms_to_time(songs_over_600_mil['length'].median()))
print(len(songs_over_600_mil), "songs earned over 500 mil streams during their time in the top 50 since 2017")
# Out:
# mean time for songs with at least 600 mil streams during their time in the top 50 is: 03:26:206433
# median time for songs with at least 600 mil streams during their time in the top 50 is: 03:20:200040
# 15 songs earned over 500 mil streams during their time in the top 50 since 2017

# %% [markdown]
# Based on the analysis above, it seems like no matter how much we filter for how much a song was streamed while it was in the top 50, the mean and median time for a hit song still hovers around at 3:20.

# %%
#isolate peak years, months, and weeks
final_df['peak_year'] = final_df['peak_date'].apply(lambda x: x.year)
final_df['peak_month'] = final_df['peak_date'].apply(lambda x: x.month)
final_df['peak_week'] = final_df['peak_date'].apply(lambda x: x.isocalendar()[1])

#normalize tempos
final_df['tempo_normalized'] = final_df['tempo'] / final_df['tempo'].max()

#normalize lengths
final_df['length_normalized'] = final_df['length'] / final_df['length'].max()

# %%
#group data by year/month with mean data
df_grpd_ym = final_df.groupby(['peak_year','peak_month']).mean().reset_index()
df_grpd_ym
# Out:
#     peak_year  peak_month  streams_2017_to_present  total_streams_2020s  \
# 0        2017           1             3.283118e+07         0.000000e+00
# 1        2017           2             7.817144e+07         0.000000e+00
# 2        2017           3             5.357339e+07         0.000000e+00
# 3        2017           4             1.447942e+08         0.000000e+00
# 4        2017           5             7.870167e+07         0.000000e+00
# ..        ...         ...                      ...                  ...
# 58       2021          11             1.891243e+07         1.874489e+07
# 59       2021          12             6.279268e+07         5.398529e+07
# 60       2022           1             4.124590e+07         4.124590e+07
# 61       2022           2             2.477528e+07         2.477528e+07
# 62       2022           3             9.640304e+06         9.640304e+06
#
#     peak_week_streams         length  popularity  acousticness  danceability  \
# 0        7.085109e+06  229888.058824   75.588235      0.172365      0.744294
# 1        8.747127e+06  218045.000000   13.000000      0.660000      0.692000
# 2        9.555294e+06  232293.533333   74.666667      0.105587      0.759133
# 3        2.152991e+07  239202.571429   75.857143      0.167963      0.677714
# 4        8.513141e+06  197651.086957   67.130435      0.218012      0.725913
# ..                ...            ...         ...           ...           ...
# 58       1.178810e+07  241872.016667   74.633333      0.301528      0.597733
# 59       1.311535e+07  184431.647059   66.911765      0.414896      0.581029
# 60       1.064801e+07  187744.632653   77.489796      0.199356      0.683898
# 61       8.348943e+06  211974.416667   77.500000      0.177244      0.702625
# 62       6.603530e+06  165018.750000   87.750000      0.435750      0.669000
#
#       energy  ...    2017-05-12    2017-05-05    2017-04-28  2017-04-21  \
# 0   0.618588  ...  2.401335e+06  2.518441e+06  2.574150e+06         0.0
# 1   0.220000  ...  7.228668e+06  7.762262e+06  8.227998e+06         0.0
# 2   0.518267  ...  3.775640e+06  3.893395e+06  4.088558e+06         0.0
# 3   0.579476  ...  8.303257e+06  9.387156e+06  1.047852e+07         0.0
# 4   0.621609  ...  4.828023e+06  3.776336e+06  2.878715e+06         0.0
# ..       ...  ...           ...           ...           ...         ...
# 58  0.553117  ...  0.000000e+00  0.000000e+00  0.000000e+00         0.0
# 59  0.520294  ...  0.000000e+00  0.000000e+00  0.000000e+00         0.0
# 60  0.608857  ...  0.000000e+00  0.000000e+00  0.000000e+00         0.0
# 61  0.643667  ...  0.000000e+00  0.000000e+00  0.000000e+00         0.0
# 62  0.499250  ...  0.000000e+00  0.000000e+00  0.000000e+00         0.0
#
#       2017-04-14    2017-04-07    2017-03-31  peak_week  tempo_normalized  \
# 0   3.462409e+06  6.159888e+06  4.972690e+06   1.000000          0.578966
# 1   8.244591e+06  8.747127e+06  8.575615e+06   8.000000          0.482615
# 2   5.450607e+06  8.426619e+06  9.348220e+06  11.333333          0.625979
# 3   1.968746e+07  4.954428e+06  4.560054e+06  15.000000          0.626974
# 4   1.856859e+06  1.873440e+06  1.777149e+06  19.869565          0.588988
# ..           ...           ...           ...        ...               ...
# 58  0.000000e+00  0.000000e+00  0.000000e+00  44.916667          0.592386
# 59  0.000000e+00  0.000000e+00  0.000000e+00  48.882353          0.600791
# 60  0.000000e+00  0.000000e+00  0.000000e+00   2.081633          0.630548
# 61  0.000000e+00  0.000000e+00  0.000000e+00   6.250000          0.612187
# 62  0.000000e+00  0.000000e+00  0.000000e+00   9.000000          0.544357
#
#     length_normalized
# 0            0.375005
# 1            0.355686
# 2            0.378929
# 3            0.390200
# 4            0.322419
# ..                ...
# 58           0.394554
# 59           0.300855
# 60           0.306259
# 61           0.345784
# 62           0.269187
#
# [63 rows x 278 columns]

# %%
#graph out trends over the years 
plt.figure(figsize=(60,120))
grid = sns.FacetGrid(data=df_grpd_ym, col='peak_year', height=5)

grid.map(plt.axhline, y=0.5, ls=":", c=".5")

grid.map(plt.plot, "peak_month", "danceability", marker="x", color='r', label='danceability')
grid.map(plt.plot, "peak_month", "energy", marker=".", color='grey', label='energy')
grid.map(plt.plot, "peak_month", "acousticness", marker="v", color='b', label='acousticness')
grid.map(plt.plot, "peak_month", "instrumentalness", marker="^", color='g', label='instrumentalness')
grid.map(plt.plot, "peak_month", "speechiness", marker="s", color='violet', label='speechiness')
grid.map(plt.plot, "peak_month", "tempo_normalized", marker=".", color='purple', label='tempo_normalized')
grid.map(plt.plot, "peak_month", "length_normalized", marker="v", color='orange', label='length_normalized')

grid.set(xticks=np.arange(13), yticks=[0, 1], 
         xlim=(0.5,12.5), ylim=(-0.1,1.1), 
         ylabel='Value', xlabel='')

plt.legend(loc='lower center', bbox_to_anchor=(-1.1, -0.2), ncol=5, fontsize=12)

plt.show()

# %%
#group data by year/month with median data
df_grpd_ym = final_df.groupby(['peak_year','peak_month']).median().reset_index()
df_grpd_ym

#graph trends over the years
plt.figure(figsize=(60,120))
grid = sns.FacetGrid(data=df_grpd_ym, col='peak_year', height=5)

grid.map(plt.axhline, y=0.5, ls=":", c=".5")

grid.map(plt.plot, "peak_month", "danceability", marker="x", color='r', label='danceability')
grid.map(plt.plot, "peak_month", "energy", marker=".", color='grey', label='energy')
grid.map(plt.plot, "peak_month", "acousticness", marker="v", color='b', label='acousticness')
grid.map(plt.plot, "peak_month", "instrumentalness", marker="^", color='g', label='instrumentalness')
grid.map(plt.plot, "peak_month", "speechiness", marker="s", color='violet', label='speechiness')
grid.map(plt.plot, "peak_month", "tempo_normalized", marker=".", color='purple', label='tempo_normalized')
grid.map(plt.plot, "peak_month", "length_normalized", marker="v", color='orange', label='length_normalized')

grid.set(xticks=np.arange(13), yticks=[0, 1], 
         xlim=(0.5,12.5), ylim=(-0.1,1.1), 
         ylabel='Value', xlabel='')

plt.legend(loc='lower center', bbox_to_anchor=(-1.1, -0.2), ncol=5, fontsize=12)

plt.show()

# %%
#group data by year/month using mean data FILTERING for songs with over 100 mil streams
df_grpd_ym = songs_over_100_mil.groupby(['peak_year','peak_month']).mean().reset_index()
df_grpd_ym

#graph data
plt.figure(figsize=(60,120))
grid = sns.FacetGrid(data=df_grpd_ym, col='peak_year', height=5)

grid.map(plt.axhline, y=0.5, ls=":", c=".5")

grid.map(plt.plot, "peak_month", "danceability", marker="x", color='r', label='danceability')
grid.map(plt.plot, "peak_month", "energy", marker=".", color='grey', label='energy')
grid.map(plt.plot, "peak_month", "acousticness", marker="v", color='b', label='acousticness')
grid.map(plt.plot, "peak_month", "instrumentalness", marker="^", color='g', label='instrumentalness')
grid.map(plt.plot, "peak_month", "speechiness", marker="s", color='violet', label='speechiness')
grid.map(plt.plot, "peak_month", "tempo_normalized", marker=".", color='purple', label='tempo_normalized')
grid.map(plt.plot, "peak_month", "length_normalized", marker="v", color='orange', label='length_normalized')

grid.set(xticks=np.arange(13), yticks=[0, 1], 
         xlim=(0.5,12.5), ylim=(-0.1,1.1), 
         ylabel='Value', xlabel='')

plt.legend(loc='lower center', bbox_to_anchor=(-1.1, -0.2), ncol=5, fontsize=12)

plt.show()

# %%
#group data by year/month using mean data FILTERING for songs with over 100 mil streams
df_grpd_ym = songs_over_100_mil.groupby(['peak_year','peak_month']).median().reset_index()
df_grpd_ym

#graph data
plt.figure(figsize=(60,120))
grid = sns.FacetGrid(data=df_grpd_ym, col='peak_year', height=5)

grid.map(plt.axhline, y=0.5, ls=":", c=".5")

grid.map(plt.plot, "peak_month", "danceability", marker="x", color='r', label='danceability')
grid.map(plt.plot, "peak_month", "energy", marker=".", color='grey', label='energy')
grid.map(plt.plot, "peak_month", "acousticness", marker="v", color='b', label='acousticness')
grid.map(plt.plot, "peak_month", "instrumentalness", marker="^", color='g', label='instrumentalness')
grid.map(plt.plot, "peak_month", "speechiness", marker="s", color='violet', label='speechiness')
grid.map(plt.plot, "peak_month", "tempo_normalized", marker=".", color='purple', label='tempo_normalized')
grid.map(plt.plot, "peak_month", "length_normalized", marker="v", color='orange', label='length_normalized')

grid.set(xticks=np.arange(13), yticks=[0, 1], 
         xlim=(0.5,12.5), ylim=(-0.1,1.1), 
         ylabel='Value', xlabel='')

plt.legend(loc='lower center', bbox_to_anchor=(-1.1, -0.2), ncol=5, fontsize=12)

plt.show()

# %%
final_df[['streams_2017_to_present','total_streams_2020s'
          ,'peak_week_streams','length','acousticness'
         ,'danceability','energy','instrumentalness','liveness'
         ,'loudness','mode','speechiness','tempo'
          ,'valence']].hist(figsize=(30,15), bins=50)

plt.show()

# %%
sns.set_style('whitegrid')
sns.lmplot('streams_2017_to_present','length', data=final_df
           , palette='coolwarm',size=8,aspect=1
           , scatter_kws={"s":3})
